# %% [markdown]
# # ETF Headlines Sentiment

# %%
# Initial imports
import os
import poras as pd
from dotenv import load_dotenv
from newsapi import NewsApiClient
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
load_dotenv()
# Out:
# True

# %%
# Read your api key environment variable
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the SPY - S&P 500 ETF Trust news articles
spy_headlines = newsapi.get_everything(q="Apple" or "AAPL" or "Microsoft" or "MSFT" or "Amazon" or "AMZN" or "Facebook" or "FB" or "Tesla" or "TSLA" or "Google" or "GOOGL" or "GOOG" or "Berkshire Hathaway" or "Johnson & Johnson" or "JNJ" or "JP Morgan" or "JPM",
                                           language="en",
                                           sort_by="relevancy")
spy_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 34578,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Cherlynn Low',
#    'title': 'Two weeks with Apple Fitness+',
#    'description': 'I’m at the stage of my pandemic fitness routine where if I finish a workout without having yelled in frustration, I have to wonder if the session was too easy. Whether it’s because I’ve grown bored or I’m getting stronger, I’ve struggled to find exercise vide…',
#    'url': 'https://www.engadget.com/apple-fitness-plus-review-two-weeks-test-watch-music-workout-160058155.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2F01953680-4aee-11eb-acfb-589043d0b91b&client=amp-blogside-v2&signature=62e57f529183d8248c2b9e8a568eafc3d27c4f0d',
#    'publishedAt': '2020-12-31T16:15:58Z',
#    'content': 'That’s something you won’t find on services from Fitbit and Samsung, which also offer workout content alongside their wearables. Similar to Fitness +, Fitbit Premium costs $10 a month and includes a … [+3957 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Sarah Perez',
#    'title': 'Apple’s new editorial franchise, Apple Podcasts Spotlight, to highlight interesting creators',
#    'description': 'Apple today announced a new editorial franchise called Apple Podcasts Spotlight, which aims to highlight rising podcast creators in the U.S. The editorial team at Apple will select new podcast creators to feature every month and then give them prominent scree…',
#    'url': 'http://techcrunch.com/2021/01/19/apples-new-editorial-franchise-apple-podcasts-spotlight-to-highlight-interesting-creators/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/podcasts-spotlight.jpg?w=703',
#    'publishedAt': '2021-01-19T16:41:16Z',
#    'content': 'Apple today announced a new editorial franchise called Apple Podcasts Spotlight, which aims to highlight rising podcast creators in the U.S. The editorial team at Apple will select new podcast creato… [+4215 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Brendan Hesse',
#    'title': "Get an Extra Year of Repairs for Your Older MacBook's Display",
#    'description': 'Apple is extending free repair eligibility for several older MacBook models facing known screen issues.Read more...',
#    'url': 'https://lifehacker.com/get-an-extra-year-of-repairs-for-your-older-macbooks-di-1846088496',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/lafwyy1nwwwgxctlwscd.jpg',
#    'publishedAt': '2021-01-20T15:30:00Z',
#    'content': 'Apple is extending free repair eligibility for several older MacBook models facing known screen issues.\r\nFirst, Apple has extended the 13-inch MacBook Pros Backlight Service Program by a year. The pr… [+1781 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Aisha Jordan',
#    'title': 'How to Get Apple TV+ Free for a Year',
#    'description': 'Apple is expanding its free trial program to give you even more time to sample Apple TV+ at no cost. The streaming service is home to a growing slate of original programming—recently including Justin Timberlake’s Palmer, M. Night Shyamalan’s Servant, and The …',
#    'url': 'https://lifehacker.com/how-to-get-apple-tv-free-for-a-year-1846087742',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/fllg9zczptny332nzkrt.jpg',
#    'publishedAt': '2021-01-19T22:00:00Z',
#    'content': 'Apple is expanding its free trial program to give you even more time to sample Apple TV+ at no cost. The streaming service is home to a growing slate of original programmingrecently including Justin … [+2247 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': 'Apple is once again extending TV+ free trials',
#    'description': 'Apple will once again give some of its customers a few extra months of TV+. Since 2019, the company has offered a free one-year trial of the service with the purchase of a new device. When Apple first announced the promotion, it was supposed to expire on Nove…',
#    'url': 'https://www.engadget.com/apple-extends-tv-plus-free-trials-again-212827285.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2Fed21af50-5775-11eb-9cff-140776d0a3b8&client=amp-blogside-v2&signature=c0c35d83155a1cc4eba4d5e52f17a376b6be920e',
#    'publishedAt': '2021-01-15T21:28:27Z',
#    'content': 'Apple will once again give some of its customers a few extra months of TV+. Since 2019, the company has offered a free one-year trial of the service with the purchase of a new device. When Apple firs… [+688 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': 'Up Your Selfie Video Game With This Apple Watch Hack',
#    'description': 'For those who haven’t yet splurged on a fancier setup for recording videos at home, know that your smartphone’s camera (ideally coupled with a better microphone that you clip to your body) is good enough in most cases—the rear-facing camera(s), that is. The f…',
#    'url': 'https://lifehacker.com/up-your-selfie-video-game-with-this-apple-watch-hack-1846000983',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/umwkduqpwham1zlqmz4a.jpg',
#    'publishedAt': '2021-01-06T20:00:00Z',
#    'content': 'For those who havent yet splurged on a fancier setup for recording videos at home, know that your smartphones camera (ideally coupled with a better microphone that you clip to your body) is good enou… [+1889 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Nick Summers',
#    'title': 'Apple will build a learning hub in Atlanta as part of its racial equity pledge',
#    'description': 'Apple has shed more light on its $100 million pledge to improve racial equity. Today, the company announced that it will be making a $25 million contribution to the Propel Center, a learning hub designed for members of the HBCU (Historically Black Colleges an…',
#    'url': 'https://www.engadget.com/apple-racial-equity-justice-propel-center-developer-academy-detroit-131109867.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F7517ff00-559f-11eb-bead-9878f87ad180&client=amp-blogside-v2&signature=5fb739ab62b2121dc3adeb3f3722b68d9fc3d39a',
#    'publishedAt': '2021-01-13T13:11:09Z',
#    'content': 'In its press release, Apple also promised to open a “first of its kind” Apple Developer Academy in Detroit. It will help and inspire young Black people to be better creators, coders and entrepreneurs… [+1227 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jay Peters',
#    'title': 'Apple is removing Parler from the App Store',
#    'description': 'Apple has removed Parler from the App Store. Apple follows Google in removing the app, which is known for being conservative-friendly and having less stringent moderation than other social media platforms.',
#    'url': 'https://www.theverge.com/2021/1/9/22221730/apple-removes-suspends-bans-parler-app-store',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/bEspe2VM_QH315QC-wUtGt5WL_c=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/11477047/acastro_180604_1777_apple_wwdc_0001.jpg',
#    'publishedAt': '2021-01-10T00:47:15Z',
#    'content': 'Google removed the app from the Play Store Friday evening\r\nIllustration by Alex Castro / The Verge\r\nApple is removing Parler from the App Store, following accusations that the social media app was fo… [+3575 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tom Warren',
#    'title': 'Intel has to be better than ‘lifestyle company’ Apple at making CPUs, says new CEO',
#    'description': 'Intel’s new CEO is already preparing to go up against Apple and other competitors. Pat Gelsinger reportedly told Intel employees that the company has to be better than Apple at making products for PCs.',
#    'url': 'https://www.theverge.com/2021/1/15/22232554/intel-ceo-apple-lifestyle-company-cpus-comment',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/Rx9fFJvWgXsEH2kK3VzLj3Arhrs=/0x109:2048x1181/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22237506/intellogo.jpg',
#    'publishedAt': '2021-01-15T12:59:42Z',
#    'content': 'Intel prepares to battle Apples M1 chips\r\nIntels new CEO, Pat Gelsinger, doesnt start his new role until February, but hes already prepping the company to take on Apples M1 chips. The Oregonian, a lo… [+2236 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Anthony Ha',
#    'title': 'Daily Crunch: Apple might be working on a VR headset',
#    'description': 'A new report suggests there’s a pricey Apple VR headset in the works, Facebook’s Oversight Board will examine one of the social network’s most consequential decisions and we review the Samsung Galaxy S21 Ultra. This is your Daily Crunch for January 21, 2021. …',
#    'url': 'http://techcrunch.com/2021/01/21/daily-crunch-apple-might-be-working-on-a-vr-headset/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2019/03/GettyImages-1090132112.jpg?w=711',
#    'publishedAt': '2021-01-21T23:10:09Z',
#    'content': 'A new report suggests there’s a pricey Apple VR headset in the works, Facebook’s Oversight Board will examine one of the social network’s most consequential decisions and we review the Samsung Galaxy… [+3231 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
#    'author': 'Stan Schroeder',
#    'title': 'Hyundai and Apple are talking about Apple Car production',
#    'description': 'The Apple Car is turning from a myth to a potential product.\xa0\nFollowing the recent report that Apple is looking into building a car and launching it by 2024, Korean automaker Hyundai has confirmed to CNBC that Apple has discussed the product with "a variety o…',
#    'url': 'https://mashable.com/article/hyundai-apple-car/',
#    'urlToImage': 'https://mondrian.mashable.com/2021%252F01%252F08%252Fac%252Fc8aae592701848f19f30ae1e0a80540d.9a726.jpg%252F1200x630.jpg?signature=ptjpgRHcNG42cBf-nQFJVROI9nI=',
#    'publishedAt': '2021-01-08T09:32:39Z',
#    'content': 'The Apple Car is turning from a myth to a potential product.\xa0\r\nFollowing the recent report that Apple is looking into building a car and launching it by 2024, Korean automaker Hyundai has confirmed t… [+1522 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Brian Heater',
#    'title': 'Apple suspend Parler from App Store',
#    'description': 'Following reports of a warning to site developers sent earlier this Apple today confirmed that it has pulled right wing social media platform Parler from the App Store. Apple tells TechCrunch, We have always supported diverse points of view being represented …',
#    'url': 'http://techcrunch.com/2021/01/09/apple-suspend-parler-from-app-store/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/05/trump-white-house-GettyImages-1210843226.jpg?w=652',
#    'publishedAt': '2021-01-10T00:50:01Z',
#    'content': 'Following reports of a warning to site developers sent earlier this Apple today confirmed that it has pulled right wing social media platform Parler from the App Store.\r\nApple tells TechCrunch,\r\nWe h… [+3743 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Richard Lawler',
#    'title': 'Hyundai confirms discussions about building a car with Apple',
#    'description': 'Last month Reuters reported that Apple’s Project Titan self-driving electric car effort could produce a vehicle by 2024 or so, and now there are more rumors suggesting the company is serious about getting into the business. Earlier today a Bloomberg report fo…',
#    'url': 'https://www.engadget.com/apple-car-hyundai-021027258.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-images%2F2019-05%2F435339e0-734b-11e9-adff-495fd4484d17&client=amp-blogside-v2&signature=1e4bc139977a8a0997ef996d21440ca6c87fac6b',
#    'publishedAt': '2021-01-08T02:10:27Z',
#    'content': 'Last month Reutersreported that Apple’s Project Titan self-driving electric car effort could produce a vehicle by 2024 or so, and now there are more rumors suggesting the company is serious about get… [+599 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'David Murphy',
#    'title': "Ward Off Security Risks With Apple's New Security and Privacy Guide",
#    'description': 'We try to cover just about everything you can do with your iPhone, but even if you feel like you’ve mastered Apple’s smartphone, there’s always something new you can learn. To help stay vigilant about the people (and companies) that can access your device, da…',
#    'url': 'https://lifehacker.com/ward-off-security-risks-with-apples-new-security-and-pr-1845935513',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/o9tzu8vyidqw5hca6ufn.jpg',
#    'publishedAt': '2020-12-23T15:00:00Z',
#    'content': 'We try to cover just about everything you can do with your iPhone, but even if you feel like youve mastered Apples smartphone, theres always something new you can learn. To help stay vigilant about t… [+6002 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': 'Apple promises to fix ultrawide monitor support on M1 Macs',
#    'description': 'Life isn’t pleasant right now if you want to pair an M1 Mac with an ultrawide monitor, but help is on the way. Macworld and 9to5Mac have learned that Apple is promising a macOS update to fix a lack of supported resolutions on ultrawide and super-ultrawide mon…',
#    'url': 'https://www.engadget.com/apple-m1-mac-ultrawide-monitor-support-fix-150002118.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2Fc9e27390-45f4-11eb-b9ff-a58815484427&client=amp-blogside-v2&signature=83f0403a37f66e78951c1572716211f8d5c5244d',
#    'publishedAt': '2020-12-24T15:00:02Z',
#    'content': 'Life isn’t pleasant right now if you want to pair an M1 Mac with an ultrawide monitor, but help is on the way. Macworld and 9to5Mac have learned that Apple is promising a macOS update to fix a lack o… [+439 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Nathan Ingraham',
#    'title': 'Apple, Amazon and Tesla supplier accused of using forced labor',
#    'description': 'According to an investigation by The Washington Post and the Tech Transparency Project, companies including Apple, Amazon and Tesla are sourcing parts from a Chinese supplier that allegedly uses forced Muslim labor. The Tech Transparency Project found documen…',
#    'url': 'https://www.engadget.com/apple-amazon-tesla-suppier-forced-labor-accusations-163641059.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2F1bdf8690-49ee-11eb-bffb-177685ffdafb&client=amp-blogside-v2&signature=1e829bfe8338dc4038da916bb209621374940181',
#    'publishedAt': '2020-12-29T16:36:41Z',
#    'content': 'An Apple spokesperson told the publication that the company confirmed Lens Technology “has not received any labor transfers of Uyghur workers from Xinjiang.” The company’s supplier progress report st… [+3132 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Cherlynn Low',
#    'title': 'How to make the most of your new Apple Watch',
#    'description': 'So you’ve been given or bought yourself an Apple Watch for the holidays. Congrats! Whether you’re a first-time smartwatch user or just new to watchOS, wearing an Apple Watch can feel like a big change in your daily life. You don’t want to just strap it on and…',
#    'url': 'https://www.engadget.com/apple-watch-setup-guide-2020-140037235.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2F239fefe0-4634-11eb-b7ef-e8f1c7618de9&client=amp-blogside-v2&signature=d79326eff7928969b4bfc82203381797fa050473',
#    'publishedAt': '2020-12-26T14:00:37Z',
#    'content': 'During the setup, you’ll be asked to turn on things like SOS and automatic watchOS updates, and it’s a good idea to enable both. SOS allows you to quickly make a call to local emergency responders by… [+4363 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Steve Dent',
#    'title': "Apple Watch prototype exposes the company's 'Ultra' security testing program",
#    'description': 'A video leak appears to show a Watch prototype and reveals how Apple gets such devices to developers while still keeping them under a veil of “ultra” security. Released by a leak site called Apple Demo and first discovered via The Verge, it shows a Watch deve…',
#    'url': 'https://www.engadget.com/watch-prototype-leak-reveals-apples-ultra-security-testing-program-135014542.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2020-12%2Fc4ca9430-49de-11eb-bd96-980804b7fc9f&client=amp-blogside-v2&signature=80105c8cfb73c827eabdad6b866518cb6dab1c0d',
#    'publishedAt': '2020-12-29T13:50:28Z',
#    'content': 'The device is a good deal larger than a Watch and has a home button but no crown. Once turned on, it shows the Watch apps, including Apple’s internal testing software. One of those, the Lisa tester (… [+473 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Apple says a record $540 million was spent on apps this New Year's Day",
#    'description': 'If you thought Apple device owners would splurge on apps during a holiday season when they were stuck at home... you guessed correctly. Apple has revealed that the App Store broke a single-day spending record on New Year’s Day, with people spending over $540 …',
#    'url': 'https://www.engadget.com/apple-app-store-spending-record-new-years-day-164624878.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F4fb625a0-5038-11eb-be9f-799fb9df070d&client=amp-blogside-v2&signature=a9095299aab5b19c930dd611aa1fdfd6c63b017d',
#    'publishedAt': '2021-01-06T16:46:24Z',
#    'content': 'If you thought Apple device owners would splurge on apps during a holiday season when they were stuck at home... you guessed correctly. Apple has revealed that the App Store broke a single-day spendi… [+441 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Catie Keck',
#    'title': "Where's the Apple TV Dongle?",
#    'description': 'A new Apple TV could be arriving in 2021, but how will it compete with so many powerful streaming devices when it retails for three times the cost?Read more...',
#    'url': 'https://gizmodo.com/wheres-the-apple-tv-dongle-1845958647',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/mdtmpcseqfema9nzgpx4.jpg',
#    'publishedAt': '2020-12-29T14:00:00Z',
#    'content': 'A new Apple TV could be arriving in 2021, but how will it compete with so many powerful streaming devices when it retails for three times the cost?\r\nThis year saw the release of several streaming sti… [+2990 chars]'}]}

# %%
# Fetch the XLF - Financial Sector news articles
finance_headlines = newsapi.get_everything(q="American Financial Sector" or "Bank of America" or "JP Morgan" or "Wells Fargo" or "Morgan Stanley" or "Berkshire Hathaway" or "Goldman Sachs" or "Charles Schwab" or "Fidelity", 
                                           language="en",
                                           sort_by="relevancy")
finance_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 1430,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'Activist hedge fund manager Daniel Loeb takes on Intel, plans launch of new VC fund',
#    'description': 'Third Point, the activist hedge fund run by Daniel Loeb, is busy in the waning days of 2020. It’s had great returns despite huge turbulence early in the pandemic — Reuters says that it is up 12.3% for the year as of earlier this month — and the firm clearly s…',
#    'url': 'http://techcrunch.com/2020/12/30/third-point-intel-venture-fund/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-187750775.jpg?w=601',
#    'publishedAt': '2020-12-30T16:39:23Z',
#    'content': 'Third Point, the activist hedge fund run by Daniel Loeb, is busy in the waning days of 2020. Its had great returns despite huge turbulence early in the pandemic Reuters says that it is up 12.3% for t… [+1656 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Will Dunham, Andy Sullivan',
#    'title': 'Las Vegas casino magnate, U.S. Republican donor Sheldon Adelson dies - Reuters',
#    'description': "American casino mogul Sheldon Adelson, who built lavish gambling palaces that made him one of the world's richest men and became a potent supporter of U.S. President Donald Trump and Israeli Prime Minister Benjamin Netanyahu, has died at age 87.",
#    'url': 'https://www.reuters.com/article/usa-adelson-int/las-vegas-casino-magnate-us-republican-donor-sheldon-adelson-dies-idUSKBN29I09C',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210113&t=2&i=1547572507&r=LYNXMPEH0C04F&w=800',
#    'publishedAt': '2021-01-13T02:44:00Z',
#    'content': '(Reuters) - American casino mogul Sheldon Adelson, who built lavish gambling palaces that made him one of the worlds richest men and became a potent supporter of U.S. President Donald Trump and Israe… [+4822 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Alicja Siekierska',
#    'title': 'WestJet unveils plan to return Boeing 737 Max to service - Yahoo Canada Finance',
#    'description': "<ol><li>WestJet unveils plan to return Boeing 737 Max to service\xa0\xa0Yahoo Canada Finance\r\n</li><li>WestJet's 737 MAX: Behind the Scenes\xa0\xa0WestJet\r\n</li><li>WestJet planning to fly 737 Max jets this month, pending Transport Canada OK\xa0\xa0CBC.ca\r\n</li><li>American Ai…",
#    'url': 'https://ca.finance.yahoo.com/news/west-jet-unveils-plan-to-return-boeing-737-max-to-service-162259556.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/tI_xwO7TakW1cn_dBmZmzQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMzMz/https://s.yimg.com/os/creatr-uploaded-images/2021-01/688da290-503a-11eb-ba76-a1cc60ac2d96',
#    'publishedAt': '2021-01-06T16:22:00Z',
#    'content': '(Bloomberg) -- Following are the minutes of the Federal Reserves Open Market Committee meeting on Dec. 16:A joint meeting of the Federal Open Market Committee and the Board of Governors was held by v… [+50172 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Marley Jay',
#    'title': 'Buy these 30 stocks that handily beat the market in 2020 and are poised for the best global returns in 2021, RBC says',
#    'description': "Summary List PlacementPredicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\nA group of RBC's top stock researchers are taking their shot once again by updating their list of 30 to…",
#    'url': 'https://www.businessinsider.com/stock-picks-to-buy-in-2021-market-rbc-top-recommendations-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff4861d6056b60018721f18?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T16:01:00Z',
#    'content': "Predicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\r\nA group of RBC's top stock researchers are taking their shot onc… [+1463 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Luc Cohen, Marianna Parraga',
#    'title': 'Special Report: UAE emerges as hub for companies helping Venezuela avoid U.S. oil sanctions - Reuters',
#    'description': 'In June, the United States imposed sanctions on half a dozen oil tankers managed by established shipping firms. It was a major escalation of American attempts to choke off Venezuela’s oil trade.',
#    'url': 'https://www.reuters.com/article/venezuela-oil-uae-specialreport-int-idUSKBN2930YE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201229&t=2&i=1546043845&r=LYNXMPEGBS0H1&w=800',
#    'publishedAt': '2020-12-29T11:33:00Z',
#    'content': 'NEW YORK (Reuters) - In June, the United States imposed sanctions on half a dozen oil tankers managed by established shipping firms. It was a major escalation of American attempts to choke off Venezu… [+15498 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Luc Cohen, Marianna Parraga',
#    'title': 'Special Report: UAE emerges as hub for companies helping Venezuela avoid U.S. oil sanctions - Reuters UK',
#    'description': 'In June, the United States imposed sanctions on half a dozen oil tankers managed by established shipping firms. It was a major escalation of American attempts to choke off Venezuela’s oil trade.',
#    'url': 'https://www.reuters.com/article/us-venezuela-oil-uae-specialreport-idUKKBN2930Y6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201229&t=2&i=1546043558&r=LYNXMPEGBS0GZ&w=800',
#    'publishedAt': '2020-12-29T11:29:00Z',
#    'content': 'NEW YORK (Reuters) - In June, the United States imposed sanctions on half a dozen oil tankers managed by established shipping firms. It was a major escalation of American attempts to choke off Venezu… [+15477 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Maiya Keidan, Rod Nickel',
#    'title': 'Hedge funds bet on recovery in 2021 - Reuters',
#    'description': 'Some global hedge fund investors are going into 2021 optimistic about a speedy snap-back from the economic challenges related to the coronavirus pandemic.',
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-hedgefunds-yearend-idUSKBN2990IJ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210104&t=2&i=1546505590&r=LYNXMPEH0308H&w=800',
#    'publishedAt': '2021-01-04T06:00:00Z',
#    'content': 'TORONTO (Reuters) - Some global hedge fund investors are going into 2021 optimistic about a speedy snap-back from the economic challenges related to the coronavirus pandemic.\r\nFILE PHOTO: George Wash… [+3958 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'Futures grind higher as Democrats win Senate control - Reuters',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://www.reuters.com/article/us-usa-stocks-idUSKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:17:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'Futures grind higher as Democrats win Senate control - Reuters UK',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://uk.reuters.com/article/us-usa-stocks-idUSKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:17:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'US STOCKS-Futures grind higher as Democrats win Senate control - Reuters UK',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://uk.reuters.com/article/us-usa-stocks-idUKKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:10:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Kane Wu',
#    'title': 'Investment deal expected to bolster European dealmaking in China - Reuters Canada',
#    'description': "European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the world's second-largest economy and the European Union agreed to an investment deal last month, lawyers and bankers say.",
#    'url': 'https://www.reuters.com/article/us-china-eu-investments-idUSKBN29C0LE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546914651&r=LYNXMPEH060CT&w=800',
#    'publishedAt': '2021-01-07T06:02:00Z',
#    'content': 'HONG KONG (Reuters) - European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the worlds second-largest economy and the European Uni… [+3335 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Kane Wu',
#    'title': 'Investment deal expected to bolster European dealmaking in China - Reuters India',
#    'description': "European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the world's second-largest economy and the European Union agreed to an investment deal last month, lawyers and bankers say.",
#    'url': 'https://in.reuters.com/article/us-china-eu-investments-idINKBN29C0LE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546918726&r=LYNXMPEH060E2&w=800',
#    'publishedAt': '2021-01-07T06:41:00Z',
#    'content': 'HONG KONG (Reuters) - European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the worlds second-largest economy and the European Uni… [+3501 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Kane Wu',
#    'title': 'Investment deal expected to bolster European dealmaking in China - Reuters UK',
#    'description': "European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the world's second-largest economy and the European Union agreed to an investment deal last month, lawyers and bankers say.",
#    'url': 'https://in.reuters.com/article/us-china-eu-investments-idUKKBN29C0LE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546918726&r=LYNXMPEH060E2&w=800',
#    'publishedAt': '2021-01-07T05:55:00Z',
#    'content': 'HONG KONG (Reuters) - European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the worlds second-largest economy and the European Uni… [+3501 chars]'},
#   {'source': {'id': None, 'name': 'BNNBloomberg.ca'},
#    'author': 'Bloomberg News',
#    'title': "France objects to Couche-Tard's US$20B Carrefour bid - BNN",
#    'description': "<ol><li>France objects to Couche-Tard's US$20B Carrefour bid\xa0\xa0BNN\r\n</li><li>Investors question Couche-Tard's bid for Carrefour as food retail not an expertise: Analyst\xa0\xa0BNN Bloomberg\r\n</li><li>Shares plunge, analysts scratch heads after Couche-Tard makes $25B…",
#    'url': 'http://www.bnnbloomberg.ca/france-says-not-in-favor-of-couche-tard-buying-carrefour-1.1548111',
#    'urlToImage': 'http://www.bnnbloomberg.ca/polopoly_fs/1.1548112!/fileimage/httpImage/image.jpg_gen/derivatives/landscape_620/pedestrians-pass-a-carrefour-market-supermarket-operated-by-carrefour-sa-in-paris-france-on-wednesday-jan-13-2021-alimentation-couche-tard-inc-the-canadian-convenience-store-operator-that-owns-the-circle-k-chain-is-exploring-a-takeover-of-french-grocer-carrefour-sa-a-deal-that-would-create-a-trans-atlantic-retail-giant.jpg',
#    'publishedAt': '2021-01-13T22:22:58Z',
#    'content': 'A $20 billion takeover proposal by Alimentation Couche-Tard Inc. for Frances Carrefour SA faces initial government opposition, casting doubt on prospects for the transatlantic retail deal.\r\nThe pande… [+4134 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Casey Sullivan',
#    'title': "Sixth Street just inked its second insurance deal of 2021, showcasing private equity's gold rush into the space",
#    'description': 'Summary List PlacementInvestment firm Sixth Street Partners has agreed to buy the insurance company Talcott Resolution for $2 billion, the latest sign that the private-equity industry is licking its chops at the long-term, steady returns offered by annuities …',
#    'url': 'https://www.businessinsider.com/sixth-street-buying-insurance-talcott-private-equity-2-billion-convex-2021-1',
#    'urlToImage': 'https://i.insider.com/600887aae3d62500185fd75a?width=1200&format=jpeg',
#    'publishedAt': '2021-01-20T20:02:26Z',
#    'content': 'Investment firm Sixth Street Partners has agreed to buy the insurance company Talcott Resolution for $2 billion, the latest sign that the private-equity industry is licking its chops at the long-term… [+3639 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Joseph Ax, Maria Caspani',
#    'title': 'Champagne on Inauguration Day? Try antacid, Democrats say, as Trump era finally ends - Reuters',
#    'description': "Marge Hobley has waited four years for the day she could finally celebrate the end of Donald Trump's chaotic presidency.",
#    'url': 'https://www.reuters.com/article/us-usa-biden-liberals-idUSKBN29P0I4',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210120&t=2&i=1548400540&r=LYNXMPEH0J095&w=800',
#    'publishedAt': '2021-01-20T06:16:22Z',
#    'content': '(Reuters) - Marge Hobley has waited four years for the day she could finally celebrate the end of Donald Trumps chaotic presidency.\r\nFILE PHOTO: A view of the stage ahead of the 59th Presidential Ina… [+4997 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mike Butcher',
#    'title': 'Israel’s startup ecosystem powers ahead, amid a year of change',
#    'description': 'But it’s been hard to argue against this position in the last ten years, as the country powered ahead, famously producing ground-breaking startups like Waze, which was eventually picked up by Google for over $1 billion in 2013. Waze’s 100 employees received a…',
#    'url': 'http://techcrunch.com/2021/01/21/israels-startup-ecosystem-powers-ahead-amid-a-year-of-change/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2016/07/israelsunrise.jpg?w=603',
#    'publishedAt': '2021-01-21T12:01:34Z',
#    'content': 'Released in 2011 Start-up Nation: The Story of Israel’s Economic Miracle was a book that laid claim to the idea that Israel was an unusual type of country. It had produced and was poised to produce, … [+8492 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Breakingviews columnists',
#    'title': 'Breakingviews - Corona Capital: Icahn, Productivity, Natixis - Reuters India',
#    'description': 'Corona Capital is a column updated throughout the day by Breakingviews columnists around the world with short, sharp pandemic-related insights.',
#    'url': 'https://in.reuters.com/article/us-health-coronavirus-finance-breakingvi-idINKBN2991X1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210104&t=2&i=1546563728&r=LYNXMPEH030WA&w=800',
#    'publishedAt': '2021-01-04T16:42:00Z',
#    'content': 'NEW YORK/LONDON/HONG KONG (Reuters Breakingviews) - Corona Capital is a column updated throughout the day by Breakingviews columnists around the world with short, sharp pandemic-related insights.\r\nA … [+6822 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Andrea Riquier',
#    'title': 'ETF Wrap: ETF Wrap: Stagflation, space, crypto and conversions',
#    'description': 'ETF Wrap is a briefing of what investors need to know about the exchange-traded fund sector, including exclusive commentary and interviews on the industry from MarketWatch',
#    'url': 'https://www.marketwatch.com/story/etf-wrap-stagflation-space-crypto-and-conversions-11610643607',
#    'urlToImage': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#    'publishedAt': '2021-01-14T17:00:00Z',
#    'content': 'Back in 2015, when the Federal Reserve prepared to raise interest rates for the first time in a decade, there were a few popular narratives in the financial media. Would the market infrastructure, th… [+7422 chars]'}]}

# %%
# Fetch the XLK - Tecnology Sector news articles
tech_headlines = newsapi.get_everything(q="American Technology Sector" or "technology distruption" or  "cybersecurity" or "semiconductors" or "Apple" or "Microsoft" or "AAPL" or "MSFT" or "Visa" or "Nvidia" or "NDVA" or "Paypal" or "Salesforce" or "CRM",
                                           language="en",
                                           sort_by="relevancy")
tech_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 1500,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'FAA approves first commercial drone flights with no on-site pilots',
#    'description': 'Farms and other agricultural operations in certain rural areas in the US can now use robotic drones to take images of or gather data on their crops. The FAA has approved Massachusetts-based American Robotics’ request to be able to deploy automated drones with…',
#    'url': 'https://www.engadget.com/faa-approves-first-commercial-automated-drone-flights-192554778.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F0c302c50-5825-11eb-9f9b-a5564cb624af&client=amp-blogside-v2&signature=47264f60bf9ce4d37e98148f2699ef455901c997',
#    'publishedAt': '2021-01-16T19:25:54Z',
#    'content': 'The company won the FAA’s trust by testing its technology for four years across eight states — last year, it flew as many as 10 autonomous flights a day to capture agriculture imagery and other data.… [+1090 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Walter Thompson',
#    'title': 'Inadequate federal privacy regulations leave US startups lagging behind Europe',
#    'description': 'I believe startups in the United States should be demanding that legislators deliver a federal privacy law.',
#    'url': 'http://techcrunch.com/2021/01/11/inadequate-federal-privacy-regulations-leave-us-startups-lagging-behind-europe/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-172878844.jpg?w=598',
#    'publishedAt': '2021-01-11T16:35:22Z',
#    'content': 'A new law to follow seems unlikely to have featured on many business wishlists this holiday season, particularly if that law concerned data privacy. Digital privacy management is an area that takes c… [+5919 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Joanna Swash',
#    'title': 'Use Technology to Give Your Team Superpowers',
#    'description': 'The symbiotic relationship between people and technology will power future business success.',
#    'url': 'https://www.entrepreneur.com/article/359489',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1608590173-wonderwoman-2017-promo.jpg',
#    'publishedAt': '2021-01-04T20:25:00Z',
#    'content': 'January\r\n4, 2021\r\n5 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nThe relationship between humanity and technology has been accentuated in these recent times but, perhaps,… [+5596 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Marley Jay',
#    'title': 'Buy these 30 stocks that handily beat the market in 2020 and are poised for the best global returns in 2021, RBC says',
#    'description': "Summary List PlacementPredicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\nA group of RBC's top stock researchers are taking their shot once again by updating their list of 30 to…",
#    'url': 'https://www.businessinsider.com/stock-picks-to-buy-in-2021-market-rbc-top-recommendations-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff4861d6056b60018721f18?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T16:01:00Z',
#    'content': "Predicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\r\nA group of RBC's top stock researchers are taking their shot onc… [+1463 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'US Blacklists Xiaomi in Widening Assault on China Tech',
#    'description': "Xiaomi plunged a record 10% after the Trump administration blacklisted China's No. 2 smartphone maker and 10 other companies, broadening efforts to undercut the expansion of the country's technology sector. From a report, shared by dxxt: The U.S. has targeted…",
#    'url': 'https://news.slashdot.org/story/21/01/15/1444226/us-blacklists-xiaomi-in-widening-assault-on-china-tech',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/china_64.png',
#    'publishedAt': '2021-01-15T14:44:00Z',
#    'content': 'The Fine Print: The following comments are owned by whoever posted them. We are not responsible for them in any way.'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Supriya R',
#    'title': 'US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill - Reuters',
#    'description': "Futures tracking the S&P 500 and the Nasdaq were at record levels on Monday as President Donald Trump's move to sign into law a long-awaited $2.3 trillion pandemic aid bill bolstered bets on a vaccine-led economic recovery.",
#    'url': 'https://www.reuters.com/article/us-usa-stocks-idUSKBN292101',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201228&t=2&i=1545959094&r=LYNXMPEGBR0GQ&w=800',
#    'publishedAt': '2020-12-28T12:30:00Z',
#    'content': '(Reuters) - Futures tracking the S&amp;P 500 and the Nasdaq were at record levels on Monday as President Donald Trumps move to sign into law a long-awaited $2.3 trillion pandemic aid bill bolstered b… [+2220 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Walter Thompson',
#    'title': 'What a Facebook Photos product manager thinks about antitrust',
#    'description': 'We may pick a battle with Facebook and win, but lose the larger war. Losing that war may mean pushing the next Instagram out of Silicon Valley.',
#    'url': 'http://techcrunch.com/2020/12/22/what-a-facebook-photos-pm-thinks-about-antitrust/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-1227830807.jpg?w=599',
#    'publishedAt': '2020-12-22T16:51:01Z',
#    'content': 'Leading up to Facebooks acquisition of Instagram, I was the product manager in charge of Facebook Photos. Mark Zuckerberg had bought my previous company, Divvyshot, one of the first iOS photo-sharing… [+9011 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Medha Singh',
#    'title': 'US STOCKS-Wall Street at record highs as Democrats take control of Senate - Reuters UK',
#    'description': 'US STOCKS-Wall Street at record highs as Democrats take control of Senate\xa0\xa0Reuters UK',
#    'url': 'https://uk.reuters.com/article/usa-stocks-idUKL4N2JI2XN',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T16:00:00Z',
#    'content': '(For a Reuters live blog on U.S., UK and European stock markets, click LIVE/ or type LIVE/ in a news window.)\r\n* Walgreens top gainer on Dow after profit beat\r\n* Weekly jobless claims dip unexpectedl… [+2816 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Ambar Warrick, Shreyashi Sanyal',
#    'title': 'EMERGING MARKETS-Latam FX up on prospect of Democrat senate; oil exporters lead gains - Reuters India',
#    'description': "* Mexico, Colombian currencies both add 1% * EM bonds under pressure * Brazil's real flat as virus fears weigh (Updates prices throughout) By Ambar Warrick and Shreyashi Sanyal Jan 6 (Reuters) - The Mexican and Colombian pesos gained on Wednesday tracking hig…",
#    'url': 'https://www.reuters.com/article/emerging-markets-latam-idINL1N2JH1QW',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-06T19:45:00Z',
#    'content': "* Mexico, Colombian currencies both add 1%\r\n * EM bonds under pressure\r\n * Brazil's real flat as virus fears weigh\r\n(Updates prices throughout)\r\n By Ambar Warrick and Shreyashi Sanyal\r\n Jan 6 (Reuter… [+2956 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Ambar Warrick, Shreyashi Sanyal',
#    'title': 'EMERGING MARKETS-Latam FX up on prospect of Democrat senate; oil exporters lead gains - Reuters UK',
#    'description': "* Mexico, Colombian currencies both add 1% * EM bonds under pressure * Brazil's real flat as virus fears weigh (Updates prices throughout) By Ambar Warrick and Shreyashi Sanyal Jan 6 (Reuters) - The Mexican and Colombian pesos gained on Wednesday tracking hig…",
#    'url': 'https://uk.reuters.com/article/emerging-markets-latam-idUKL1N2JH1QW',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-06T19:44:00Z',
#    'content': "* Mexico, Colombian currencies both add 1%\r\n * EM bonds under pressure\r\n * Brazil's real flat as virus fears weigh\r\n(Updates prices throughout)\r\n By Ambar Warrick and Shreyashi Sanyal\r\n Jan 6 (Reuter… [+2956 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Maiya Keidan, Rod Nickel',
#    'title': 'Hedge funds bet on recovery in 2021 - Reuters',
#    'description': 'Some global hedge fund investors are going into 2021 optimistic about a speedy snap-back from the economic challenges related to the coronavirus pandemic.',
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-hedgefunds-yearend-idUSKBN2990IJ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210104&t=2&i=1546505590&r=LYNXMPEH0308H&w=800',
#    'publishedAt': '2021-01-04T06:00:00Z',
#    'content': 'TORONTO (Reuters) - Some global hedge fund investors are going into 2021 optimistic about a speedy snap-back from the economic challenges related to the coronavirus pandemic.\r\nFILE PHOTO: George Wash… [+3958 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mike Butcher',
#    'title': 'Israel’s startup ecosystem powers ahead, amid a year of change',
#    'description': 'But it’s been hard to argue against this position in the last ten years, as the country powered ahead, famously producing ground-breaking startups like Waze, which was eventually picked up by Google for over $1 billion in 2013. Waze’s 100 employees received a…',
#    'url': 'http://techcrunch.com/2021/01/21/israels-startup-ecosystem-powers-ahead-amid-a-year-of-change/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2016/07/israelsunrise.jpg?w=603',
#    'publishedAt': '2021-01-21T12:01:34Z',
#    'content': 'Released in 2011 Start-up Nation: The Story of Israel’s Economic Miracle was a book that laid claim to the idea that Israel was an unusual type of country. It had produced and was poised to produce, … [+8492 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Supriya R',
#    'title': 'US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill - Reuters',
#    'description': '<ol><li>US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill\xa0\xa0Reuters\r\n</li><li>Stocks jump to records as Trump signs off on coronavirus aid\xa0\xa0Fox Business\r\n</li><li>Stock market news live updates: Stocks end at record highs after Tr…',
#    'url': 'https://fr.reuters.com/article/usa-stocks-idUSL4N2J81HR',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2020-12-28T12:37:07Z',
#    'content': '(For a Reuters live blog on U.S., UK and European stock markets, click LIVE/ or type LIVE/ in a news window.)\r\n* Futures up: S&amp;P 0.7%, Dow 0.6% and Nasdaq up 0.7%\r\nDec 28 (Reuters) - Futures trac… [+2304 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Lawder, Andrea Shalal, James Pearson',
#    'title': "Trump's final trade jab may be tariffs on Vietnamese goods: experts - Reuters India",
#    'description': 'President Donald Trump is likely to unveil proposed tariffs on Vietnamese goods before he leaves office in January, currency and trade experts say, after the U.S. Treasury branded the growing U.S. trade partner a "currency manipulator" last week.',
#    'url': 'https://in.reuters.com/article/usa-trade-vietnam-idINKBN28V1YR',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545317925&r=LYNXMPEGBK14T&w=800',
#    'publishedAt': '2020-12-21T15:29:00Z',
#    'content': 'WASHINGTON/HANOI (Reuters) - President Donald Trump is likely to unveil proposed tariffs on Vietnamese goods before he leaves office in January, currency and trade experts say, after the U.S. Treasur… [+5801 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Lawder, Andrea Shalal, James Pearson',
#    'title': "Trump's final trade jab may be tariffs on Vietnamese goods - experts - Reuters UK",
#    'description': 'President Donald Trump is likely to unveil proposed tariffs on Vietnamese goods before he leaves office in January, currency and trade experts say, after the U.S. Treasury branded the growing U.S. trade partner a "currency manipulator" last week.',
#    'url': 'https://uk.reuters.com/article/usa-trade-vietnam-analysis-idUKKBN28V18F',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545288910&r=LYNXMPEGBK0NB&w=800',
#    'publishedAt': '2020-12-21T11:18:00Z',
#    'content': 'WASHINGTON/HANOI (Reuters) - President Donald Trump is likely to unveil proposed tariffs on Vietnamese goods before he leaves office in January, currency and trade experts say, after the U.S. Treasur… [+5531 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Lawder, Andrea Shalal, James Pearson',
#    'title': "Trump's final trade jab may be tariffs on Vietnamese goods - experts - Reuters UK",
#    'description': 'President Donald Trump is likely to unveil proposed tariffs on Vietnamese goods before he leaves office in January, currency and trade experts say, after the U.S. Treasury branded the growing U.S. trade partner a "currency manipulator" last week.',
#    'url': 'https://in.reuters.com/article/usa-trade-vietnam-idINL1N2J00LG',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2020-12-21T11:04:00Z',
#    'content': 'WASHINGTON/HANOI, Dec 21 (Reuters) - President Donald Trump is likely to unveil proposed tariffs on Vietnamese goods before he leaves office in January, currency and trade experts say, after the U.S.… [+5226 chars]'},
#   {'source': {'id': 'the-wall-street-journal',
#     'name': 'The Wall Street Journal'},
#    'author': 'Sarah E. Needleman',
#    'title': 'Google Employees Form Union to Push for Changes',
#    'description': 'The move, rare for Silicon Valley, comes amid growing activism in the sector',
#    'url': 'https://www.wsj.com/articles/google-employees-form-union-to-push-for-changes-11609782619',
#    'urlToImage': 'https://images.wsj.net/im-280267/social',
#    'publishedAt': '2021-01-05T04:20:53Z',
#    'content': 'A group of Google employees has formed a union to organize workers across the technology companys sprawling global operations, a rare move within Silicon Valley and one that reflects growing employee… [+6536 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Greg Robb',
#    'title': 'Economic Report: Private sector lost 123,000 jobs in December, first decline in 8 months',
#    'description': 'The private sector lost 123,000 jobs in December, the first decline since April, according to ADP data released Wednesday.',
#    'url': 'https://www.marketwatch.com/story/private-sector-lost-123-000-jobs-in-december-first-decline-in-8-months-11609940256',
#    'urlToImage': 'https://images.mktw.net/im-280938/social',
#    'publishedAt': '2021-01-06T13:37:00Z',
#    'content': 'Economists polled by MarketWatch had expected a December gain of 60,000 private sector jobs.What happened: Job losses were primarily concentrated in retail and leisure and hospitality. Private-sector… [+1262 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'The challenges for eLogistics that 2020 left in LATAM',
#    'description': 'While the pandemic halted some business operations, e-commerce soared in amounts unthinkable before 2020, representing a great opportunity for electronic logistics.',
#    'url': 'https://www.entrepreneur.com/article/362177',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1608588855-Depositphotos-36835635-l-2015.jpg',
#    'publishedAt': '2020-12-22T15:00:00Z',
#    'content': 'December\r\n22, 2020\r\n5 min read\r\nThis article was translated from our Spanish edition using AI technologies. Errors may exist due to this process.\r\nThe big theme of 2020 was, without a doubt, COVID-19… [+4508 chars]'}]}

# %%
# Fetch the XTL - Telecom Sector news articles
telecom_headlines = newsapi.get_everything(q="American Telecommunications Sector" or "IRDM" or "5G" or "INSG" or "VIAV" or "CALX" or "MSFT" or "Visa" or "Nvidia" or "NDVA" or "Paypal" or "Salesforce" or "CRM",
                                           language="en",
                                           sort_by="relevancy")
telecom_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 119,
#  'articles': [{'source': {'id': 'business-insider',
#     'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Dave Graham',
#    'title': "Analysis: Mexican president's energy reform threat faces U.S. reality check - Reuters",
#    'description': "Mexico's government is coming to realize that with a new president entering the White House on Wednesday, overturning a reform that opened Mexican energy markets to foreign investors might not be as straightforward as it thought.",
#    'url': 'https://www.reuters.com/article/mexico-usa-energy/analysis-mexican-presidents-energy-reform-threat-faces-us-reality-check-idUSL1N2J6094',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210119&t=2&i=1548343144&r=LYNXMPEH0I1E2&w=800',
#    'publishedAt': '2021-01-19T18:32:00Z',
#    'content': 'MEXICO CITY (Reuters) - Mexicos government is coming to realize that with a new president entering the White House on Wednesday, overturning a reform that opened Mexican energy markets to foreign inv… [+5169 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'USA TODAY NETWORK, Meghan Mangrum and Donovan Slack, USA TODAY NETWORK',
#    'title': 'The Nashville bombing revealed vulnerabilities in US communication networks. Now officials are demanding answers.',
#    'description': "Officials are starting to demand answers from AT&T, asking how such a telecommunications nightmare happened and how to ensure it can't happen again.",
#    'url': 'https://www.usatoday.com/story/news/nation/2021/01/02/nashville-bombing-debate-how-secure-communication-networks/4111859001/',
#    'urlToImage': 'https://www.gannett-cdn.com/presto/2020/12/31/PNAS/6cedc378-74f8-4ae9-9601-11a8432a12b4-Explopsion-123120-AN-001.jpg?crop=3599,2025,x0,y183&width=3200&height=1680&fit=bounds',
#    'publishedAt': '2021-01-02T13:26:07Z',
#    'content': 'Police bodycam video shows officers rushing people away from the area where a bomb in Nashville went off.\r\nStoryful\r\nNASHVILLE Four days after the\xa0bombing on Christmas Day in downtown Nashville cripp… [+12127 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Andrea Shalal, David Lawder',
#    'title': 'Biden to nominate Rhode Island governor for Commerce, Boston mayor for Labor - Reuters',
#    'description': 'President-elect Joe Biden will nominate Rhode Island Governor Gina Raimondo as his Commerce Department secretary and former union official and Boston Mayor Marty Walsh as Labor secretary, his transition team said late on Thursday.',
#    'url': 'https://www.reuters.com/article/us-usa-election-biden-cabinet/biden-to-nominate-rhode-island-governor-for-commerce-boston-mayor-for-labor-idINKBN29C31H',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1547021518&r=LYNXMPEH061HZ&w=800',
#    'publishedAt': '2021-01-08T01:47:38Z',
#    'content': 'WASHINGTON (Reuters) - President-elect Joe Biden will nominate Rhode Island Governor Gina Raimondo as his Commerce Department secretary and former union official and Boston Mayor Marty Walsh as Labor… [+4369 chars]'},
#   {'source': {'id': 'the-wall-street-journal',
#     'name': 'The Wall Street Journal'},
#    'author': 'Sarah E. Needleman',
#    'title': 'Google Employees Form Union to Push for Changes',
#    'description': 'The move, rare for Silicon Valley, comes amid growing activism in the sector',
#    'url': 'https://www.wsj.com/articles/google-employees-form-union-to-push-for-changes-11609782619',
#    'urlToImage': 'https://images.wsj.net/im-280267/social',
#    'publishedAt': '2021-01-05T04:20:53Z',
#    'content': 'A group of Google employees has formed a union to organize workers across the technology companys sprawling global operations, a rare move within Silicon Valley and one that reflects growing employee… [+6536 chars]'},
#   {'source': {'id': None, 'name': 'State.gov'},
#    'author': None,
#    'title': 'The Clean Network',
#    'description': 'Clean Networks is a comprehensive effort by a coalition of like-minded countries and companies to secure their critical telecommunications, Internet, cloud computing, data analytics, and 5G technologies from malign actors by relying on only trusted vendors wh…',
#    'url': 'https://www.state.gov/the-clean-network/',
#    'urlToImage': 'https://www.state.gov/wp-content/uploads/2020/06/S_5GCleanPath-scaled.jpg',
#    'publishedAt': '2021-01-10T10:00:58Z',
#    'content': 'We call on all freedom-loving nations and companies to join the Clean Network.Michael R. PompeoSecretary of State\r\nET_CN_TimelineTimeline originally from The Epoch Times\xa0: text version\r\nThe Clean Net… [+23328 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Ben Klayman, Stephen Nellis',
#    'title': "Trump's China tech war backfires on automakers as chips run short - Reuters",
#    'description': "Automakers around the world are shutting assembly lines because of a global shortage of semiconductors that in some cases has been exacerbated by the Trump administration's actions against key Chinese chip factories, industry officials said.",
#    'url': 'https://www.reuters.com/article/us-autos-tech-chips-focus/trumps-china-tech-war-backfires-on-automakers-as-chips-run-short-idUSKBN29K0GA',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210115&t=2&i=1547878068&r=LYNXMPEH0E07P&w=800',
#    'publishedAt': '2021-01-15T05:13:00Z',
#    'content': '(Reuters) - Automakers around the world are shutting assembly lines because of a global shortage of semiconductors that in some cases has been exacerbated by the Trump administrations actions against… [+5085 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Jennifer Spencer',
#    'title': 'Will Retailers Need a POS Terminal After Covid?',
#    'description': 'Traditional keypad payment terminals may be a thing of the past.',
#    'url': 'https://www.entrepreneur.com/article/361191',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1608736530-GettyImages-1141999633.jpg',
#    'publishedAt': '2020-12-25T19:15:00Z',
#    'content': 'December\r\n25, 2020\r\n5 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nUntil now, most consumers have relied on bank cards to make in-store purchases, and the seller needed o… [+5238 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Morning News Call - India, January 7 - Reuters India',
#    'description': 'To access a PDF version of this newsletter, please click here https://share.refinitiv.com/assets/newsletters/Indiamorning/MNC_IN_01072021.pdf If you would like to receive this newsletter via email, please register at: https://solutions.refinitiv.com/MNCIndiaS…',
#    'url': 'https://in.reuters.com/article/india-morningcall-idINL4N2JI0VI',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T03:31:00Z',
#    'content': 'By Reuters Staff\r\nTo access a PDF version of this newsletter, please click here here\r\nIf you would like to receive this newsletter via email, please register at:\r\nhere\r\nFACTORS TO WATCH\r\n 11:00 am: P… [+6987 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Kari McMahon',
#    'title': 'BANK OF AMERICA: Buy these 8 US stocks poised to soar in the first quarter of 2021— and avoid these 2 at all costs',
#    'description': "Summary List PlacementThis week, the S&P 500 has hit record highs above 3,800, surpassing Bank of America's year-end target of 3,800 for the S&P 500 for 2021.\nThe target was included in the bank's wider US equity outlook for 2021 released on November 24, 2020…",
#    'url': 'https://www.businessinsider.com/stocks-to-buy-q1-2021-bank-of-america-stock-picks-1',
#    'urlToImage': 'https://i.insider.com/5ff70a2e6d61c10019cce191?width=1200&format=jpeg',
#    'publishedAt': '2021-01-08T12:25:00Z',
#    'content': "This week, the S&amp;P 500 has hit record highs above 3,800, surpassing Bank of America's year-end target of 3,800 for the S&amp;P 500 for 2021.\r\nThe target was included in the bank's wider US equity… [+3583 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Hayley Cuccinello',
#    'title': 'These are the 29 most generous billionaires in America',
#    'description': 'Summary List Placement"If the public sector will not take \'personal responsibility\' for providing an adequate safety net for those in distress, private philanthropy must do so."\nThat\'s the charitable mandate George Kaiser — one of America\'s most generous (and…',
#    'url': 'https://www.businessinsider.com/most-generous-billionaires-in-america-philanthropy-charitable-giving-2020-12',
#    'urlToImage': 'https://i.insider.com/5fee0f749ff41f001883f963?width=1200&format=jpeg',
#    'publishedAt': '2020-12-31T19:30:28Z',
#    'content': '"If the public sector will not take \'personal responsibility\' for providing an adequate safety net for those in distress, private philanthropy must do so."\r\nThat\'s the charitable mandate George Kaise… [+2256 chars]'},
#   {'source': {'id': None, 'name': 'Techdirt'},
#    'author': 'Karl Bode',
#    'title': "Outgoing FCC's Last Act Is A Delusional Report That Pretends US Broadband Is Wonderful",
#    'description': 'By law, the FCC is required once a year to issue a report indicating whether quality broadband is being deployed on a "reasonable and timely basis." If not, the agency is supposed to, you know, actually do something about it. Unsurprisingly, the Pai FCC last …',
#    'url': 'https://www.techdirt.com/articles/20210120/12125346089/outgoing-fccs-last-act-is-delusional-report-that-pretends-us-broadband-is-wonderful.shtml',
#    'urlToImage': 'https://ii.techdirt.com/s/t/i/td_icon_300.png',
#    'publishedAt': '2021-01-21T14:33:30Z',
#    'content': 'from the delusion-to-the-last dept\r\nBy law, the FCC is required once a year to issue a report indicating whether quality broadband is being deployed on a "reasonable and timely basis." If not, the ag… [+6169 chars]'},
#   {'source': {'id': 'al-jazeera-english', 'name': 'Al Jazeera English'},
#    'author': 'Al Jazeera',
#    'title': 'After telecom firms, China oil giants may face US delisting next',
#    'description': 'Chinese oil firms Cnooc, PetroChina and Sinopec may be removed from US exchanges due to military links, analysts say.',
#    'url': 'https://www.aljazeera.com/economy/2021/1/4/after-the-telcos-chinese-oil-firms-may-be-next-to-face-us-delist',
#    'urlToImage': 'https://www.aljazeera.com/wp-content/uploads/2021/01/367016156.jpg?resize=1200%2C630',
#    'publishedAt': '2021-01-04T04:59:30Z',
#    'content': 'Chinese oil majors may be next in line for delisting in the US after the New York Stock Exchange said last week it would remove the Asian nations three biggest telecom companies.\r\nChinas largest offs… [+3424 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Ryan Downie)',
#    'title': '5 High-Yield Dividend Stocks to Watch',
#    'description': "Not every income investor has the same needs, but there's are companies on this list to fit the preferences of most dividend lovers' portfolios.",
#    'url': 'https://www.fool.com/investing/2021/01/04/5-high-yield-dividend-stocks-to-watch/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/606451/gettyimages-1184205598.jpg',
#    'publishedAt': '2021-01-04T14:02:00Z',
#    'content': 'Income investors are always looking for dividend stocks with high yields that can provide them with reliable cash flow. Retirees in particular often seek stable companies that are only likely to offe… [+5788 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Jodi Xu Klein jodi.klein@scmp.com',
#    'title': 'NYSE to make its second policy reversal in two days to delist Chinese telecoms stocks if US blacklist applies, source says',
#    'description': 'The New York Stock Exchange (NYSE) is committed to delisting three Chinese telecommunications companies if their subsidiaries are found to be affected by a...',
#    'url': 'https://finance.yahoo.com/news/nyse-flip-flop-delisting-chinese-093000267.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/AUSmrRL0ROolBt2YfrMbvA--~B/aD01NDg7dz05NDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/south_china_morning_post_us_228/92289e6c1f06da48c24c710b7c6f227d',
#    'publishedAt': '2021-01-06T09:30:00Z',
#    'content': 'The New York Stock Exchange (NYSE) is committed to delisting three Chinese telecommunications companies if their subsidiaries are found to be affected by a US blacklist, according to a person with kn… [+7357 chars]'},
#   {'source': {'id': None, 'name': 'Jalopnik'},
#    'author': 'Erik Shilling',
#    'title': 'Trump Gave Automakers Another Parting Gift',
#    'description': 'Trump has hurt automakers, Hyundai is big into hydrogen fuel cells, and BMW is done with subscriptions. All that and more in The Morning Shift for January 15, 2020.Read more...',
#    'url': 'https://jalopnik.com/trump-gave-automakers-another-parting-gift-1846065617',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/xivgl18ix7awxqndtdum.png',
#    'publishedAt': '2021-01-15T15:00:00Z',
#    'content': 'Trump has hurt automakers, Hyundai is big into hydrogen fuel cells, and BMW is done with subscriptions. All that and more in The Morning Shift for January 15, 2020.\r\n1st Gear: This Trump Guy Seems Ba… [+7077 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'PR Newswire',
#    'title': 'Alithya selected by AGA Benefit Solutions for 5-year technological partnership',
#    'description': 'Alithya Group inc. (TSX: ALYA) (NASDAQ: ALYA) ("Alithya"), a leader in the digital transformation sector, is proud to have been chosen by AGA Benefit...',
#    'url': 'https://finance.yahoo.com/news/alithya-selected-aga-benefit-solutions-123000776.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/wJPXaoEnJ3w.IdIKU4O9dA--~B/aD0xNjt3PTE2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/09bd6165a331c2d6911a67ae3be00121',
#    'publishedAt': '2021-01-12T12:30:00Z',
#    'content': 'The partnership reflects a vision of the future based on efficiency, performance, and growth\r\nMONTREAL, Jan. 12, 2021 /PRNewswire/ - Alithya Group inc. (TSX: ALYA) (NASDAQ: ALYA) ("Alithya"), a leade… [+2789 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'PR Newswire',
#    'title': 'ZTE publishes white paper on 5G SA commercial deployment',
#    'description': 'ZTE Corporation (0763.HK / 000063.SZ), a major international provider of telecommunications, enterprise and consumer technology solutions for the Mobile...',
#    'url': 'https://finance.yahoo.com/news/zte-publishes-white-paper-5g-034400802.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/5hyGNLhJjuLE8OobLgNUlg--~B/aD0xNjt3PTE2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/006136991c93493e2c886d5dd042b5fd',
#    'publishedAt': '2020-12-21T03:44:00Z',
#    'content': "It was among the most consequential weeks of President Donald Trump's tenure: Across the country, health care workers began receiving a lifesaving coronavirus vaccine. On Capitol Hill, lawmakers near… [+10896 chars]"},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Franklin Olakunle Amoo, Contributor, \n Franklin Olakunle Amoo, Contributor\n https://www.forbes.com/sites/franklinamoo/',
#    'title': 'How Covid-19 Did What Poverty Could Not: Convince Africa It Needed To Manufacture',
#    'description': 'Declining world demand for commodities amidst general global slowdown and pandemic driven disruptions to supply chains have combined with Africa’s difficulty procuring PPE and securing vaccine supplies to create novel resolve to develop comprehensive domestic…',
#    'url': 'https://www.forbes.com/sites/franklinamoo/2021/01/04/how-covid-19-did-what-poverty-could-not-convince-africa-it-needed-to-manufacture/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5ff2c8c9c0ac721a34a3f9f2%2F0x0.jpg%3FcropX1%3D0%26cropX2%3D990%26cropY1%3D21%26cropY2%3D578',
#    'publishedAt': '2021-01-04T07:50:49Z',
#    'content': 'Spared the worst medical effects of Covid-19 with among the worlds lowest virus infection rates and fatalities, Africa nonetheless suffered due to deep economic fallout. Declining world demand for co… [+9632 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Craig Dempsey, Forbes Councils Member, \n Craig Dempsey, Forbes Councils Member\n https://www.forbes.com/sites/forbesbusinessdevelopmentcouncil/people/craigdempsey/',
#    'title': 'The Chile-Paraguay FTA Could Create Deeper Ties For Latin America And Opportunities For Investors',
#    'description': 'To understand what advantages the Chile-Paraguay FTA promises to bring, it’s first worth considering Chile’s status as a promoter of free trade and Paraguay’s approach to trade liberalization and economic diversification.',
#    'url': 'https://www.forbes.com/sites/forbesbusinessdevelopmentcouncil/2021/01/14/the-chile-paraguay-fta-could-create-deeper-ties-for-latin-america-and-opportunities-for-investors/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5f74b8662af056fa760e7395%2F0x0.jpg',
#    'publishedAt': '2021-01-14T12:20:00Z',
#    'content': 'Managing Director &amp; Founder of the\xa0Biz Latin Hub Group.\r\ngetty\r\nChile and Paraguay recently began negotiations on a free trade agreement (FTA) that, once completed, could further solidify Chiles … [+6374 chars]'}]}

# %%
# Fetch the XLU - Utilities Sector news articles
utility_headlines = newsapi.get_everything(q="American Utilities Sector" or "NextEra" or "NEE" or "DUK" or "Duke Energy" or "Green Energy" or "SO" or "Dominion Energy" or "American Electric Power" or "Visa" or "Exelon" or "Sempra Energy" or "Xcel Energy" or "Eversource Energy" or "Public Service Enterprise" or "ConEdison",
                                           language="en",
                                           sort_by="relevancy")
utility_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 172,
#  'articles': [{'source': {'id': 'business-insider',
#     'name': 'Business Insider'},
#    'author': 'Marley Jay',
#    'title': 'Buy these 30 stocks that handily beat the market in 2020 and are poised for the best global returns in 2021, RBC says',
#    'description': "Summary List PlacementPredicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\nA group of RBC's top stock researchers are taking their shot once again by updating their list of 30 to…",
#    'url': 'https://www.businessinsider.com/stock-picks-to-buy-in-2021-market-rbc-top-recommendations-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff4861d6056b60018721f18?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T16:01:00Z',
#    'content': "Predicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\r\nA group of RBC's top stock researchers are taking their shot onc… [+1463 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Nathan Rott',
#    'title': 'Biden Moves To Have U.S. Rejoin Climate Accord',
#    'description': 'President Biden signed an executive order to have the country reenter the Paris Climate Agreement, less than four months after formally withdrawing.',
#    'url': 'https://www.npr.org/sections/inauguration-day-live-updates/2021/01/20/958923821/biden-moves-to-have-u-s-rejoin-climate-accord',
#    'urlToImage': 'https://media.npr.org/assets/img/2021/01/20/gettyimages-5010818721_wide-de0d096cf5a42901e84b58f09cf37e5d1ef8a690.jpg?s=1400',
#    'publishedAt': '2021-01-20T22:42:39Z',
#    'content': 'President Joe Biden is directing the U.S. to rejoin the international Paris Climate Agreement, which aims to cut global greenhouse gas emissions. Here, activists rally on Dec. 12, 2015.\r\nFrancois Gui… [+2719 chars]'},
#   {'source': {'id': None, 'name': 'The Motley Fool Canada'},
#    'author': None,
#    'title': '18 Top TSX Stocks to Buy for 2021 and Beyond - The Motley Fool Canada',
#    'description': '<ol><li>18 Top TSX Stocks to Buy for 2021 and Beyond\xa0\xa0The Motley Fool Canada\r\n</li><li>S&P/TSX composite edges lower in late-morning trading, U.S. stock markets up\xa0\xa0Medicine Hat News\r\n</li><li>Forget a Market Crash: These 3 Tech Stocks Are Trading at a Discou…',
#    'url': 'https://www.fool.ca/2021/01/19/18-top-tsx-stocks-to-buy-for-2021-and-beyond/',
#    'urlToImage': 'https://yw553ftvhw1iqegz29fycoyw-wpengine.netdna-ssl.com/wp-content/uploads/2016/01/1st-place_top-stocks_16-9.jpg',
#    'publishedAt': '2021-01-19T13:36:39Z',
#    'content': 'We asked our Foolish writers for their top ideas for 2021 – here are their choices:\r\nRyan Vanzo: Fairfax Financial \r\nMy top stock for 2021 is\xa0Fairfax Financial (TSX:FFH). The upcoming 12 months could… [+19699 chars]'},
#   {'source': {'id': None, 'name': 'Scientific American'},
#    'author': 'Benjamin Storrow, E&E News',
#    'title': 'Record Drop in U.S. Emissions Is No Cause for Celebration',
#    'description': 'The pandemic drove a 10.3 percent decline in greenhouse gases last year but experts expect levels to rebound in 2021\n\n-- Read more on ScientificAmerican.com',
#    'url': 'https://www.scientificamerican.com/article/record-drop-in-u-s-emissions-is-no-cause-for-celebration/',
#    'urlToImage': 'https://static.scientificamerican.com/sciam/cache/file/94D8890A-ABD0-4B33-A9CA37BADDB232F2.jpg',
#    'publishedAt': '2021-01-12T19:45:00Z',
#    'content': 'American greenhouse gas emissions fell a record 10.3% last year—the largest annual decline since World War II, according to a report released today by the Rhodium Group.\r\nBut the emission reduction—w… [+6337 chars]'},
#   {'source': {'id': None, 'name': 'The Economist'},
#    'author': 'The Economist',
#    'title': 'Is an infrastructure boom in the works?',
#    'description': 'Governments and investors have been terrible at making projects happen. Can this time be different?',
#    'url': 'https://www.economist.com/finance-and-economics/2020/12/30/is-an-infrastructure-boom-in-the-works',
#    'urlToImage': 'https://www.economist.com/img/b/1280/720/90/sites/default/files/images/print-edition/20210102_FNP002_0.jpg',
#    'publishedAt': '2020-12-30T15:55:20Z',
#    'content': 'IN THE 1920S the Lambert Flying Field in St Louis, Missouri, was a hive of innovation and celebrity. It became the first airport with a traffic-control system, waving flags at pilots. Charles Lindber… [+15823 chars]'},
#   {'source': {'id': None, 'name': 'The Economist'},
#    'author': 'The Economist',
#    'title': 'Is an infrastructure boom in the works?',
#    'description': 'Governments and investors have been terrible at making projects happen. Can this time be different?',
#    'url': 'https://www.economist.com/finance-and-economics/2021/01/02/is-an-infrastructure-boom-in-the-works',
#    'urlToImage': 'https://www.economist.com/img/b/1280/720/90/sites/default/files/images/print-edition/20210102_FNP002_0.jpg',
#    'publishedAt': '2020-12-30T16:53:19Z',
#    'content': 'IN THE 1920S the Lambert Flying Field in St Louis, Missouri, was a hive of innovation and celebrity. It became the first airport with a traffic-control system, waving flags at pilots. Charles Lindber… [+15823 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Jack Denton',
#    'title': 'Need to Know: Goldman Sachs says the S&P 500 will rise 14% in 2021. Here’s the road map',
#    'description': 'With global markets rallying on the hopes that massive economic stimulus will accompany President-elect Joe Biden’s new administration, Goldman Sachs’ projection that the S&P 500 will end 2021 at 4,300 points seems even more realistic.',
#    'url': 'https://www.marketwatch.com/story/goldman-sachs-says-the-s-p-500-will-rise-14-in-2021-heres-the-road-map-11610627051',
#    'urlToImage': 'https://images.mktw.net/im-285239/social',
#    'publishedAt': '2021-01-14T12:24:00Z',
#    'content': 'With global markets rallying on the hopes that massive economic stimulus will accompany President-elect Joe Bidens new administration, Goldman Sachs projection that the S&amp;P 500 will end 2021 at 4… [+5545 chars]'},
#   {'source': {'id': None, 'name': 'The Truth About Cars'},
#    'author': 'Timothy Cain',
#    'title': 'The Auto Enthusiast’s Realistic Christmas Wish List for the North American Auto Industry in 2020',
#    'description': 'French hot hatches. Affordable full-size wagons. Manual-shift rear-wheel-drive sports sedans under $30,000. Production versions of the Chevrolet Code 130R, Dodge Hornet, and Ford Start. The reincarnation of Isuzu’s VehiCROSS and Trooper. Standard-of-the-world…',
#    'url': 'https://www.thetruthaboutcars.com/2020/12/the-auto-enthusiasts-realistic-christmas-wish-list-for-the-north-american-auto-industry-in-2020/',
#    'urlToImage': 'https://www.thetruthaboutcars.com/wp-content/uploads/2020/12/TTAC-Christmas-wish-list-unrealistic.jpg',
#    'publishedAt': '2020-12-21T17:00:10Z',
#    'content': 'French hot hatches. Affordable full-size wagons. Manual-shift rear-wheel-drive sports sedans under $30,000. Production versions of the Chevrolet Code 130R, Dodge Hornet, and Ford Start. The reincarna… [+8577 chars]'},
#   {'source': {'id': None, 'name': 'Ctvnews.ca'},
#    'author': 'Dan Healing',
#    'title': 'Technology sector boosts TSX as Lightspeed climbs, U.S. stock markets mixed - CTV News',
#    'description': "Gains in the technology sector helped lift Canada's main stock index to a positive close as U.S. markets were mixed and the Canadian dollar lost ground against the American greenback on Tuesday.",
#    'url': 'https://www.ctvnews.ca/business/technology-sector-boosts-tsx-as-lightspeed-climbs-u-s-stock-markets-mixed-1.5241183',
#    'urlToImage': 'https://www.ctvnews.ca/polopoly_fs/1.4996181.1592925513!/httpImage/image.jpg_gen/derivatives/landscape_620/image.jpg',
#    'publishedAt': '2020-12-22T22:38:00Z',
#    'content': "TORONTO -- \r\nGains in the technology sector helped lift Canada's main stock index to a positive close as U.S. markets were mixed and the Canadian dollar lost ground against the American greenback on … [+3452 chars]"},
#   {'source': {'id': None, 'name': 'The Atlantic'},
#    'author': 'Robinson Meyer',
#    'title': 'The Weekly Planet: The 5 Biggest Climate Stories of 2020',
#    'description': 'Joe Biden’s victory isn’t on the list.',
#    'url': 'https://www.theatlantic.com/science/archive/2020/12/5-biggest-climate-stories-2020/617468/',
#    'urlToImage': 'https://cdn.theatlantic.com/thumbor/E46jx_31FuilLrvH864xeximdKg=/0x106:2496x1406/960x500/https://cdn.theatlantic.com/assets/media/img/mt/2020/12/GettyImages_625667994/original.jpg',
#    'publishedAt': '2020-12-22T21:51:00Z',
#    'content': 'Every Tuesday, our lead climate reporter brings you the big ideas, expert analysis, and vital guidance that will help you flourish on a changing planet. Sign up to get The Weekly Planet, our guide to… [+12309 chars]'},
#   {'source': {'id': None, 'name': 'Americanthinker.com'},
#    'author': None,
#    'title': 'Trump: The American David',
#    'description': 'One of President Trump’s most prescient statements to the American electorate leading up to the November vote was, “They’re not after me, they’re after you, I’m just in the way.”\xa0 The question that everyone sh...',
#    'url': 'https://www.americanthinker.com/articles/2020/12/trump_the_american_david.html',
#    'urlToImage': 'https://www.americanthinker.com/images/bucket/2020-12/226180.png',
#    'publishedAt': '2020-12-27T06:00:00Z',
#    'content': 'One of President Trump’s most prescient statements to the American electorate leading up to the November vote was, “They’re not after me, they’re after you, I’m just in the way.”\xa0 The question that e… [+9226 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Research and Markets',
#    'title': 'North American Virtual Schools Market Analysis and Forecasts to 2024 - Increasing Number of e-Learning Enrolments in the Higher Education Sector Driving Market Growth',
#    'description': 'Dublin, Jan. 15, 2021 (GLOBE NEWSWIRE) -- The "Virtual Schools Market in North America 2020-2024" report has been added to ResearchAndMarkets.com\'s offering....',
#    'url': 'https://finance.yahoo.com/news/north-american-virtual-schools-market-084300255.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/HP.E8HUfnyGeLtMAKwLgAQ--~B/aD01ODt3PTQ4MDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/globenewswire.com/93d5b27580f67db722dd7c112e43e8bc',
#    'publishedAt': '2021-01-15T08:43:00Z',
#    'content': 'Whether markets move up or down, every investor loves a bargain. Theres a thrill in finding a valuable stock at low, low price and then watching it appreciate in the mid- to long-term. The key here f… [+6057 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Golden Minerals Company',
#    'title': 'Golden Minerals Regains Compliance with NYSE American Continued Listing Standards',
#    'description': 'GOLDEN, Colo., Jan. 15, 2021 (GLOBE NEWSWIRE) -- Golden Minerals Company (NYSE American and TSX: AUMN) (“Golden Minerals”, “Golden” or “the Company...',
#    'url': 'https://finance.yahoo.com/news/golden-minerals-regains-compliance-nyse-115000809.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/Kc7zYeKOEqt7bxUsRc_7IA--~B/aD02NDU7dz0xNTEwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/globenewswire.com/c4ee95bd2a4412694f7549b1ba3a68d9',
#    'publishedAt': '2021-01-15T11:50:00Z',
#    'content': 'Whether markets move up or down, every investor loves a bargain. Theres a thrill in finding a valuable stock at low, low price and then watching it appreciate in the mid- to long-term. The key here f… [+6057 chars]'},
#   {'source': {'id': None, 'name': 'Business Wire'},
#    'author': None,
#    'title': 'Wells Fargo Utilities and High Income Fund Announces Sources of Distribution',
#    'description': 'SAN FRANCISCO--(BUSINESS WIRE)--The Wells Fargo Utilities and High Income Fund (NYSE American: ERH) released information about the sources of today’s distribution in a Notice provided to shareholders. The full text of the Notice is available below and on the …',
#    'url': 'https://www.businesswire.com/news/home/20210104005740/en/Wells-Fargo-Utilities-and-High-Income-Fund-Announces-Sources-of-Distribution',
#    'urlToImage': 'http://www.businesswire.com/images/bwlogo_square.png',
#    'publishedAt': '2021-01-04T21:10:18Z',
#    'content': 'SAN FRANCISCO--(BUSINESS WIRE)--The Wells Fargo Utilities and High Income Fund (NYSE American: ERH) released information about the sources of todays distribution in a Notice provided to shareholders.… [+9910 chars]'},
#   {'source': {'id': 'usa-today', 'name': 'USA Today'},
#    'author': 'USA TODAY NETWORK, Meghan Mangrum and Donovan Slack, USA TODAY NETWORK',
#    'title': 'The Nashville bombing revealed vulnerabilities in US communication networks. Now officials are demanding answers.',
#    'description': "Officials are starting to demand answers from AT&T, asking how such a telecommunications nightmare happened and how to ensure it can't happen again.",
#    'url': 'https://www.usatoday.com/story/news/nation/2021/01/02/nashville-bombing-debate-how-secure-communication-networks/4111859001/',
#    'urlToImage': 'https://www.gannett-cdn.com/presto/2020/12/31/PNAS/6cedc378-74f8-4ae9-9601-11a8432a12b4-Explopsion-123120-AN-001.jpg?crop=3599,2025,x0,y183&width=3200&height=1680&fit=bounds',
#    'publishedAt': '2021-01-02T13:26:07Z',
#    'content': 'Police bodycam video shows officers rushing people away from the area where a bomb in Nashville went off.\r\nStoryful\r\nNASHVILLE Four days after the\xa0bombing on Christmas Day in downtown Nashville cripp… [+12127 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'MATT OTT',
#    'title': 'US industrial production jumps 1.6% in December',
#    'description': 'U.S. industrial production rose 1.6% in December, a third straight monthly gain, but remains below its pre-pandemic level.  The December gain in industrial...',
#    'url': 'https://news.yahoo.com/us-industrial-production-jumps-1-142814449.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/5qhuCjBvhEDK3.Yuy_hiTw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMzMz/https://s.yimg.com/uu/api/res/1.2/TMSEeSAVD3ujMDEgvbl3jg--~B/aD0yNDk4O3c9Mzc0NzthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/ap.org/6be4bc9ac0b20f284a1279017a2781c4',
#    'publishedAt': '2021-01-15T14:28:14Z',
#    'content': 'SILVER SPRING, Md. (AP) U.S. industrial production rose 1.6% in December, a third straight monthly gain, but remains below its pre-pandemic level.\r\nThe December gain in industrial output followed a 0… [+1949 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'PR Newswire',
#    'title': 'Power Sustainable launches the Power Sustainable Energy Infrastructure Partnership, a $1B investment platform dedicated to the North American renewable energy sector',
#    'description': 'Today, Power Sustainable Capital Inc. ("Power Sustainable"), a global multi-platform alternative asset manager focused on long-term investments in...',
#    'url': 'https://finance.yahoo.com/news/power-sustainable-launches-power-sustainable-110000889.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/nksbb8_Thp8BlOj1dJRXiw--~B/aD0xNzg7dz00MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/prnewswire.com/94b9cbf74d512856bcee0d4b8fa2015f',
#    'publishedAt': '2021-01-19T11:00:00Z',
#    'content': '<ul><li>Select group of institutional investors including Desjardins Group as strategic anchor investor\r\n</li><li>Operationally driven strategy with Potentia Renewables and Nautilus Solar Energy\r\n</l… [+5772 chars]'},
#   {'source': {'id': None, 'name': 'Hyperallergic'},
#    'author': 'Valentina Di Liscia',
#    'title': '$900 Billion US Stimulus Package Includes $15 Billion for the Arts',
#    'description': "The deal provides crucial aid to the performing arts sector and creates two unique Smithsonian museums, one dedicated to Latinx history and the other to women's history.",
#    'url': 'http://hyperallergic.com/609947/900-billion-us-stimulus-package-includes-15-billion-for-the-arts/',
#    'urlToImage': 'https://i1.wp.com/hyperallergic.com/wp-content/uploads/2020/12/50372136078_752663632e_o-scaled.jpg?fit=2560%2C1707&quality=100&ssl=1',
#    'publishedAt': '2020-12-22T17:28:28Z',
#    'content': 'Following months of strained negotiations, the US Congress has passed a $908 billion coronavirus relief package meant to boost the nations pandemic-stricken economy. The stimulus deal includes $600 p… [+4163 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'PR Newswire',
#    'title': 'Sandvik invests in leading AI-powered manufacturing software provider Oqton',
#    'description': 'Sandvik has acquired a minority stake in the privately owned American software company Oqton, a leading provider of AI-powered manufacturing solutions that...',
#    'url': 'https://finance.yahoo.com/news/sandvik-invests-leading-ai-powered-082500159.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/cXkudM9mnMhxCcq5r_FOFA--~B/aD0xNjt3PTE2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/prnewswire.com/624cc7ab3825a61e88c574648bf2d7ed',
#    'publishedAt': '2021-01-15T08:25:00Z',
#    'content': 'Whether markets move up or down, every investor loves a bargain. Theres a thrill in finding a valuable stock at low, low price and then watching it appreciate in the mid- to long-term. The key here f… [+6057 chars]'}]}

# %%
# Fetch the XLI - Industrial Sector news articles
indust_headlines = newsapi.get_everything(q="American Industrial Sector" or "HON" or "Honeywell International" or "UNP" or "Union Pacific Corp" or "UPS" or "United Postal Service" or "Boeing" or "Raytheon" or "RTX" or "MMM" or "3M" or "Caterpillar Inc" or "GE" or "General Electric" or "LMT" or "Lockheed Martin" or "DE" or "John Deere",
                                           language="en",
                                           sort_by="relevancy")
indust_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 717,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Walter Thompson',
#    'title': 'Inadequate federal privacy regulations leave US startups lagging behind Europe',
#    'description': 'I believe startups in the United States should be demanding that legislators deliver a federal privacy law.',
#    'url': 'http://techcrunch.com/2021/01/11/inadequate-federal-privacy-regulations-leave-us-startups-lagging-behind-europe/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-172878844.jpg?w=598',
#    'publishedAt': '2021-01-11T16:35:22Z',
#    'content': 'A new law to follow seems unlikely to have featured on many business wishlists this holiday season, particularly if that law concerned data privacy. Digital privacy management is an area that takes c… [+5919 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 1-Fiat Chrysler to invest 2 bln euros in Poland, says Deputy PM - Reuters',
#    'description': 'Italian-American automaker Fiat Chrysler will invest 2 billion euros ($2.45 billion) in its plant in Tychy, Poland, Deputy Prime Minister Jaroslaw Gowin said on Tuesday, in a move that will see new hybrid and electric models produced at the factory.',
#    'url': 'https://www.reuters.com/article/fiat-poland-idUSL8N2J91JA',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2020-12-29T12:22:00Z',
#    'content': 'By Reuters Staff\r\n(Adds detail)\r\nWARSAW, Dec 29 (Reuters) - Italian-American automaker Fiat Chrysler will invest 2 billion euros ($2.45 billion) in its plant in Tychy, Poland, Deputy Prime Minister J… [+1222 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Shashank Nayar, Ambar Warrick',
#    'title': 'EMERGING MARKETS-Latam FX set for annual losses; Chilean peso outperforms - Reuters.com',
#    'description': '* Brazil stocks hit record intraday high; overall debt falls * Chilean peso set to gain 5.5% in 2020 * Coronavirus cases surge across Latin America (Updates prices, adds analyst comment) By Shashank Nayar and Ambar Warrick Dec 30 (Reuters) - Most Latin Americ…',
#    'url': 'https://www.reuters.com/article/emerging-markets-latam-idUSL1N2JA1FZ',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2020-12-30T19:54:00Z',
#    'content': '* Brazil stocks hit record intraday high; overall debt falls\r\n * Chilean peso set to gain 5.5% in 2020\r\n * Coronavirus cases surge across Latin America\r\n(Updates prices, adds analyst comment)\r\n By Sh… [+3256 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Ian Bremmer',
#    'title': "The U.S. Capitol Riot Was Years in the Making. Here's Why America Is So Divided",
#    'description': '"There is no advanced industrial democracy in the world more politically divided, or politically dysfunctional, than the United States today."',
#    'url': 'https://news.yahoo.com/u-capitol-riot-years-making-163051948.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/2bUY7j2HETPTHWjK.MEtFQ--~B/aD02ODM7dz0xMDI0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/time_72/3b6824ca01b2fb526768fa4637e36ccb',
#    'publishedAt': '2021-01-16T16:30:51Z',
#    'content': 'Pro-Trump protesters and police clash on top of the Capitol\r\nWASHINGTON DC, DISTRICT OF COLUMBIA, UNITED STATES - 2021/01/06: Pro-Trump protesters and police clash on top of the Capitol building. Rio… [+7297 chars]'},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': 'Ian Bremmer',
#    'title': 'The U.S. Capitol Riot Was Years in the Making. Here’s Why America Is So Divided',
#    'description': '"There is no advanced industrial democracy in the world more politically divided, or politically dysfunctional, than the United States today."',
#    'url': 'https://time.com/5929978/the-u-s-capitol-riot-was-years-in-the-making-heres-why-america-is-so-divided/',
#    'urlToImage': 'https://api.time.com/wp-content/uploads/2021/01/capitol-u-s-polarization.jpg?quality=85&w=1024&h=628&crop=1',
#    'publishedAt': '2021-01-16T16:30:51Z',
#    'content': 'There is no advanced industrial democracy in the world more politically divided, or politically dysfunctional, than the United States today. How did the world’s most powerful country get to this poin… [+6846 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Mike Stone',
#    'title': 'Lockheed Martin inks $4.4 billion deal to acquire Aerojet Rocketdyne - Reuters India',
#    'description': 'Lockheed Martin Corp said on Sunday it has agreed to buy U.S. rocket engine manufacturer Aerojet Rocketdyne Holdings Inc for $4.4 billion, including debt and net cash.',
#    'url': 'https://in.reuters.com/article/aerojet-m-a-lockheed-idINKBN28V0F2',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545256931&r=LYNXMPEGBK065&w=800',
#    'publishedAt': '2020-12-21T04:59:00Z',
#    'content': 'FILE PHOTO: The logo of Lockheed Martin is seen at Euronaval, the world naval defence exhibition in Le Bourget near Paris, France, October 23, 2018. REUTERS/Benoit Tessier/File photo\r\n(Reuters) - Loc… [+1674 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Ambar Warrick, Shreyashi Sanyal',
#    'title': "EMERGING MARKETS-EM FX index hits record high, Chile's peso outperforms - Reuters UK",
#    'description': "* Chilean economy expands in November * Mexican, Chilean stocks rise * MSCI EM FX index hits all-time high (Updates prices throughout, adds comments) By Ambar Warrick and Shreyashi Sanyal Jan 4 (Reuters) - Chile's peso outpaced its peers on Monday after econo…",
#    'url': 'https://uk.reuters.com/article/emerging-markets-latam-idUKL1N2JF1RP',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-04T20:02:00Z',
#    'content': '* Chilean economy expands in November\r\n * Mexican, Chilean stocks rise \r\n * MSCI EM FX index hits all-time high\r\n(Updates prices throughout, adds comments)\r\n By Ambar Warrick and Shreyashi Sanyal\r\n J… [+2918 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Nathan Rott',
#    'title': 'Biden Moves To Have U.S. Rejoin Climate Accord',
#    'description': 'President Biden signed an executive order to have the country reenter the Paris Climate Agreement, less than four months after formally withdrawing.',
#    'url': 'https://www.npr.org/sections/inauguration-day-live-updates/2021/01/20/958923821/biden-moves-to-have-u-s-rejoin-climate-accord',
#    'urlToImage': 'https://media.npr.org/assets/img/2021/01/20/gettyimages-5010818721_wide-de0d096cf5a42901e84b58f09cf37e5d1ef8a690.jpg?s=1400',
#    'publishedAt': '2021-01-20T22:42:39Z',
#    'content': 'President Joe Biden is directing the U.S. to rejoin the international Paris Climate Agreement, which aims to cut global greenhouse gas emissions. Here, activists rally on Dec. 12, 2015.\r\nFrancois Gui… [+2719 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'Futures grind higher as Democrats win Senate control - Reuters',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://www.reuters.com/article/us-usa-stocks-idUSKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:17:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'Futures grind higher as Democrats win Senate control - Reuters UK',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://uk.reuters.com/article/us-usa-stocks-idUSKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:17:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain',
#    'title': 'US STOCKS-Futures grind higher as Democrats win Senate control - Reuters UK',
#    'description': 'U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a rise in weekly claims.',
#    'url': 'https://uk.reuters.com/article/us-usa-stocks-idUKKBN29C1KT',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546953669&r=LYNXMPEH060U1&w=800',
#    'publishedAt': '2021-01-07T12:10:00Z',
#    'content': '(Reuters) - U.S. stock index futures climbed on Thursday as expectations of more pandemic aid under a Democrat-controlled U.S. Congress lifted the mood ahead of jobs data, which is expected to show a… [+1908 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bracing for Biden climate rules, U.S. Chamber asks Congress to make laws - Reuters',
#    'description': "The U.S. Chamber of Commerce, the country's biggest and most influential business lobby group, shifted its position on climate change on Tuesday, saying Congress should pass laws pushing companies to limit greenhouse gas emissions.",
#    'url': 'https://www.reuters.com/article/us-usa-climate-business-idUSKBN29O2JN',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210119&t=2&i=1548359876&r=LYNXMPEH0I1JM&w=800',
#    'publishedAt': '2021-01-19T21:06:00Z',
#    'content': 'By Reuters Staff\r\nWASHINGTON (Reuters) - The U.S. Chamber of Commerce, the countrys biggest and most influential business lobby group, shifted its position on climate change on Tuesday, saying Congre… [+2073 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Medha Singh',
#    'title': 'US STOCKS-Wall Street at record highs as Democrats take control of Senate - Reuters UK',
#    'description': 'US STOCKS-Wall Street at record highs as Democrats take control of Senate\xa0\xa0Reuters UK',
#    'url': 'https://uk.reuters.com/article/usa-stocks-idUKL4N2JI2XN',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T16:00:00Z',
#    'content': '(For a Reuters live blog on U.S., UK and European stock markets, click LIVE/ or type LIVE/ in a news window.)\r\n* Walgreens top gainer on Dow after profit beat\r\n* Weekly jobless claims dip unexpectedl… [+2816 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gabriel Crossley, Stella Qiu',
#    'title': "China's stunning export comeback has factories scrambling for workers - Reuters India",
#    'description': "China's manufacturing recovery, fuelled in part by demand from COVID-constrained consumers abroad, has soared past expectations this year, so much so that factories are now struggling to fill a shortage of blue-collar workers to clear mounting orders.",
#    'url': 'https://in.reuters.com/article/us-china-economy-manufacturing-idINKBN28V0AL',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545249954&r=LYNXMPEGBK04A&w=800',
#    'publishedAt': '2020-12-21T03:09:00Z',
#    'content': 'BEIJING (Reuters) - Chinas manufacturing recovery, fuelled in part by demand from COVID-constrained consumers abroad, has soared past expectations this year, so much so that factories are now struggl… [+5015 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gabriel Crossley, Stella Qiu',
#    'title': "China's stunning export comeback has factories scrambling for workers - Reuters UK",
#    'description': "China's manufacturing recovery, fuelled in part by demand from COVID-constrained consumers abroad, has soared past expectations this year, so much so that factories are now struggling to fill a shortage of blue-collar workers to clear mounting orders.",
#    'url': 'https://uk.reuters.com/article/uk-china-economy-manufacturing-idUKKBN28V0AE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545250017&r=LYNXMPEGBK04D&w=800',
#    'publishedAt': '2020-12-21T03:08:00Z',
#    'content': 'BEIJING (Reuters) - Chinas manufacturing recovery, fuelled in part by demand from COVID-constrained consumers abroad, has soared past expectations this year, so much so that factories are now struggl… [+5015 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gabriel Crossley, Stella Qiu',
#    'title': "China's stunning export comeback has factories scrambling for workers - Reuters India",
#    'description': "China's manufacturing recovery, fuelled in part by demand from COVID-constrained consumers abroad, has soared past expectations this year, so much so that factories are now struggling to fill a shortage of blue-collar workers to clear mounting orders.",
#    'url': 'https://in.reuters.com/article/china-economy-manufacturing-idINKBN28V0BE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545251341&r=LYNXMPEGBK04L&w=800',
#    'publishedAt': '2020-12-21T03:29:00Z',
#    'content': 'BEIJING (Reuters) - Chinas manufacturing recovery, fuelled in part by demand from COVID-constrained consumers abroad, has soared past expectations this year, so much so that factories are now struggl… [+5015 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Medha Singh',
#    'title': 'Wall Street set for higher open as Democrats take control of Senate - Reuters India',
#    'description': "Wall Street's main indexes were set to open higher on Thursday as bets on more pandemic aid under a Democrat-controlled U.S. Congress eclipsed data showing elevated levels of unemployment claims.",
#    'url': 'https://in.reuters.com/article/usa-stocks-idINKBN29C1SI',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546964493&r=LYNXMPEH060XP&w=800',
#    'publishedAt': '2021-01-07T13:56:00Z',
#    'content': '(Reuters) - Wall Streets main indexes were set to open higher on Thursday as bets on more pandemic aid under a Democrat-controlled U.S. Congress eclipsed data showing elevated levels of unemployment … [+2550 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Alicja Siekierska',
#    'title': 'WestJet unveils plan to return Boeing 737 Max to service - Yahoo Canada Finance',
#    'description': "<ol><li>WestJet unveils plan to return Boeing 737 Max to service\xa0\xa0Yahoo Canada Finance\r\n</li><li>WestJet's 737 MAX: Behind the Scenes\xa0\xa0WestJet\r\n</li><li>WestJet planning to fly 737 Max jets this month, pending Transport Canada OK\xa0\xa0CBC.ca\r\n</li><li>American Ai…",
#    'url': 'https://ca.finance.yahoo.com/news/west-jet-unveils-plan-to-return-boeing-737-max-to-service-162259556.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/tI_xwO7TakW1cn_dBmZmzQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMzMz/https://s.yimg.com/os/creatr-uploaded-images/2021-01/688da290-503a-11eb-ba76-a1cc60ac2d96',
#    'publishedAt': '2021-01-06T16:22:00Z',
#    'content': '(Bloomberg) -- Following are the minutes of the Federal Reserves Open Market Committee meeting on Dec. 16:A joint meeting of the Federal Open Market Committee and the Board of Governors was held by v… [+50172 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Associated Press',
#    'title': 'Tribal leaders blast congressman opposed to Biden nomination',
#    'description': "A group of Native American tribes in a Minnesota congressman's district is rebuking him for his attempts to derail President-elect Joe Biden's pick for...",
#    'url': 'https://news.yahoo.com/tribal-leaders-blast-congressman-opposed-164413633.html',
#    'urlToImage': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo-1200x1200.png',
#    'publishedAt': '2021-01-19T16:44:13Z',
#    'content': "DULUTH, Minn. (AP) A group of Native American tribes in a Minnesota congressman's district is rebuking him for his attempts to derail President-elect Joe Biden's pick for Interior secretary.\r\nIf conf… [+2241 chars]"}]}

# %%
# Fetch the XLV - Healthcare Sector news articles
health_headlines = newsapi.get_everything(q="American Healthcare Sector" or "JNJ" or "Johnson & Johnson" or "UnitedHealth Group" or "UNH" or "MRK" or "Merck & Co" or "PFE" or "Pfizer" or "ABT" or "Abbott Laboroatories" or "ABBV" or "AbbVie Inc" or "TMO" or "Thermo Fisher" or "Visa" or "Nvidia" or "BMY" or "Bristol-Myers Squibb",
                                           language="en",
                                           sort_by="relevancy")
health_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 556,
#  'articles': [{'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Danny Crichton',
#    'title': 'Activist hedge fund manager Daniel Loeb takes on Intel, plans launch of new VC fund',
#    'description': 'Third Point, the activist hedge fund run by Daniel Loeb, is busy in the waning days of 2020. It’s had great returns despite huge turbulence early in the pandemic — Reuters says that it is up 12.3% for the year as of earlier this month — and the firm clearly s…',
#    'url': 'http://techcrunch.com/2020/12/30/third-point-intel-venture-fund/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/12/GettyImages-187750775.jpg?w=601',
#    'publishedAt': '2020-12-30T16:39:23Z',
#    'content': 'Third Point, the activist hedge fund run by Daniel Loeb, is busy in the waning days of 2020. Its had great returns despite huge turbulence early in the pandemic Reuters says that it is up 12.3% for t… [+1656 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 2-CANADA STOCKS-TSX hits record high on boost from pot stocks, U.S. stimulus bets - Reuters',
#    'description': "Canada's main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took control of the Senate.",
#    'url': 'https://www.reuters.com/article/canada-stocks-idUSL4N2JI3A3',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T16:28:00Z',
#    'content': 'By Reuters Staff\r\n(Updates prices to add milestone)\r\nJan 7 (Reuters) - Canadas main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an ex… [+1828 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'CANADA STOCKS-TSX rises on boost from pot stocks, U.S. stimulus bets - Reuters',
#    'description': "Canada's main stock index rose on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took control of the Senate.",
#    'url': 'https://www.reuters.com/article/canada-stocks-idUSL4N2JI314',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T15:28:00Z',
#    'content': 'By Reuters Staff\r\nJan 7 (Reuters) - Canadas main stock index rose on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took… [+1777 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 2-CANADA STOCKS-TSX hits record high on boost from pot stocks, U.S. stimulus bets - Reuters UK',
#    'description': "Canada's main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took control of the Senate.",
#    'url': 'https://uk.reuters.com/article/canada-stocks-idUKL4N2JI3A3',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T16:25:00Z',
#    'content': 'By Reuters Staff\r\n(Updates prices to add milestone)\r\nJan 7 (Reuters) - Canadas main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an ex… [+1828 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Kane Wu',
#    'title': 'Investment deal expected to bolster European dealmaking in China - Reuters Canada',
#    'description': "European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the world's second-largest economy and the European Union agreed to an investment deal last month, lawyers and bankers say.",
#    'url': 'https://www.reuters.com/article/us-china-eu-investments-idUSKBN29C0LE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546914651&r=LYNXMPEH060CT&w=800',
#    'publishedAt': '2021-01-07T06:02:00Z',
#    'content': 'HONG KONG (Reuters) - European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the worlds second-largest economy and the European Uni… [+3335 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Kane Wu',
#    'title': 'Investment deal expected to bolster European dealmaking in China - Reuters India',
#    'description': "European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the world's second-largest economy and the European Union agreed to an investment deal last month, lawyers and bankers say.",
#    'url': 'https://in.reuters.com/article/us-china-eu-investments-idINKBN29C0LE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546918726&r=LYNXMPEH060E2&w=800',
#    'publishedAt': '2021-01-07T06:41:00Z',
#    'content': 'HONG KONG (Reuters) - European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the worlds second-largest economy and the European Uni… [+3501 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Kane Wu',
#    'title': 'Investment deal expected to bolster European dealmaking in China - Reuters UK',
#    'description': "European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the world's second-largest economy and the European Union agreed to an investment deal last month, lawyers and bankers say.",
#    'url': 'https://in.reuters.com/article/us-china-eu-investments-idUKKBN29C0LE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210107&t=2&i=1546918726&r=LYNXMPEH060E2&w=800',
#    'publishedAt': '2021-01-07T05:55:00Z',
#    'content': 'HONG KONG (Reuters) - European companies are expected to hunt for assets in China, mainly in insurance, healthcare and automobile sectors, after the worlds second-largest economy and the European Uni… [+3501 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Krystal Hu',
#    'title': 'Hinge Health eyes IPO after raising $300 million - Reuters UK',
#    'description': 'Hinge Health plans to go public next year after raising $300 million from investors led by Coatue Management and Tiger Global Management at a valuation of $3 billion, the U.S. digital health firm’s chief executive told Reuters in an interview.',
#    'url': 'https://uk.reuters.com/article/us-hinge-health-ipo-idUKKBN29B20R',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-06T15:34:00Z',
#    'content': '(Reuters) - Hinge Health plans to go public next year after raising $300 million from investors led by Coatue Management and Tiger Global Management at a valuation of $3 billion, the U.S. digital hea… [+1830 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Marley Jay',
#    'title': 'Buy these 30 stocks that handily beat the market in 2020 and are poised for the best global returns in 2021, RBC says',
#    'description': "Summary List PlacementPredicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\nA group of RBC's top stock researchers are taking their shot once again by updating their list of 30 to…",
#    'url': 'https://www.businessinsider.com/stock-picks-to-buy-in-2021-market-rbc-top-recommendations-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff4861d6056b60018721f18?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T16:01:00Z',
#    'content': "Predicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\r\nA group of RBC's top stock researchers are taking their shot onc… [+1463 chars]"},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Mike Butcher',
#    'title': 'Israel’s startup ecosystem powers ahead, amid a year of change',
#    'description': 'But it’s been hard to argue against this position in the last ten years, as the country powered ahead, famously producing ground-breaking startups like Waze, which was eventually picked up by Google for over $1 billion in 2013. Waze’s 100 employees received a…',
#    'url': 'http://techcrunch.com/2021/01/21/israels-startup-ecosystem-powers-ahead-amid-a-year-of-change/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2016/07/israelsunrise.jpg?w=603',
#    'publishedAt': '2021-01-21T12:01:34Z',
#    'content': 'Released in 2011 Start-up Nation: The Story of Israel’s Economic Miracle was a book that laid claim to the idea that Israel was an unusual type of country. It had produced and was poised to produce, … [+8492 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Megan Hernbroth and Lydia Ramsey Pflanzer',
#    'title': 'The 26 billion-dollar startups to watch that are revolutionizing healthcare in 2021',
#    'description': "Summary List PlacementThe financial calamities predicted at the beginning of the coronavirus pandemic didn't materialize for most healthcare startups.\xa0\nThe industry's up-and-coming private companies largely benefited from the one-two punch of financial concer…",
#    'url': 'https://www.businessinsider.com/billion-dollar-startups-that-are-revolutionizing-healthcare-2021-1',
#    'urlToImage': 'https://i.insider.com/5fab19f6f7d1cb0019e3b04e?width=1200&format=jpeg',
#    'publishedAt': '2021-01-11T17:47:09Z',
#    'content': None},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'Ravie Lakshmanan',
#    'title': 'Pardon the Intrusion #34: Cyberbaddies had a field day in 2020',
#    'description': 'Subscribe to this bi-weekly newsletter here! Welcome to the latest edition of Pardon The Intrusion, TNW’s bi-weekly newsletter in which we explore the wild world of security. 2020 is finally over. The year was already surreal and tough enough, thanks to the p…',
#    'url': 'https://thenextweb.com/?p=1333374',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/tnw?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2019%2F09%2Fptl-newsletter-hed.png&signature=c4f12fef9a1a81c9ecf46fee2ba1a103',
#    'publishedAt': '2021-01-08T03:38:29Z',
#    'content': 'Subscribe to this bi-weekly newsletter here!\r\nWelcome to the latest edition of Pardon The Intrusion, TNWs bi-weekly newsletter in which we explore the wild world of security.\r\n2020 is finally over. T… [+6936 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Megan Hernbroth, Blake Dodge, Dr. Catherine Schuster-Bruce, Shelby Livingston and Andrew Dunn',
#    'title': '29 top VCs share their best 2021 healthcare predictions, from a surge in startups addressing where medicine falls short to a big year for digital health IPOs',
#    'description': "Summary List PlacementIt's difficult to imagine what 2021 has in store, after a pandemic-ravaged 2020.\nBut when it comes to the healthcare industry, investors are predicting certain events and trends are bound to transpire in the coming year.\xa0\nIn 2020, the he…",
#    'url': 'https://www.businessinsider.com/healthcare-investors-and-vcs-share-2021-predictions-2020-12',
#    'urlToImage': 'https://i.insider.com/5fe0e990d366e6001809961d?width=1200&format=jpeg',
#    'publishedAt': '2020-12-21T18:59:50Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'The Motley Fool Canada'},
#    'author': None,
#    'title': '18 Top TSX Stocks to Buy for 2021 and Beyond - The Motley Fool Canada',
#    'description': '<ol><li>18 Top TSX Stocks to Buy for 2021 and Beyond\xa0\xa0The Motley Fool Canada\r\n</li><li>S&P/TSX composite edges lower in late-morning trading, U.S. stock markets up\xa0\xa0Medicine Hat News\r\n</li><li>Forget a Market Crash: These 3 Tech Stocks Are Trading at a Discou…',
#    'url': 'https://www.fool.ca/2021/01/19/18-top-tsx-stocks-to-buy-for-2021-and-beyond/',
#    'urlToImage': 'https://yw553ftvhw1iqegz29fycoyw-wpengine.netdna-ssl.com/wp-content/uploads/2016/01/1st-place_top-stocks_16-9.jpg',
#    'publishedAt': '2021-01-19T13:36:39Z',
#    'content': 'We asked our Foolish writers for their top ideas for 2021 – here are their choices:\r\nRyan Vanzo: Fairfax Financial \r\nMy top stock for 2021 is\xa0Fairfax Financial (TSX:FFH). The upcoming 12 months could… [+19699 chars]'},
#   {'source': {'id': None, 'name': 'Dark Reading'},
#    'author': 'Jai Vijayan Contributing Writer',
#    'title': 'Healthcare Organizations Bear the Brunt of Cyberattacks Amid Pandemic',
#    'description': 'In the past two months alone, attacks against the sector soared 45% - more than double the rate of other sectors, Check Point says.',
#    'url': 'https://www.darkreading.com/risk/healthcare-organizations-bear-the-brunt-of-cyberattacks-amid-pandemic/d/d-id/1339844',
#    'urlToImage': 'https://twimgs.com/nojitter/darkreading/dr-logo.jpg',
#    'publishedAt': '2021-01-06T22:55:00Z',
#    'content': 'In the past two months alone, attacks against the sector soared 45% - more than double the rate of other sectors, Check Point says.Hospitals and other healthcare organizations bore the brunt of cyber… [+7218 chars]'},
#   {'source': {'id': None, 'name': 'Quartz India'},
#    'author': 'Annalisa Merelli',
#    'title': 'Why Jeff Bezos, Warren Buffett, and Jamie Dimon gave up on their venture to disrupt US healthcare',
#    'description': "If Jeff Bezos, Warren Buffett, and Jamie Dimon can't fix US healthcare, then who can?",
#    'url': 'https://qz.com/1952225/why-amazon-berkshire-hathaway-and-jpmorgans-haven-failed/',
#    'urlToImage': 'https://cms.qz.com/wp-content/uploads/2021/01/2020-12-15T132423Z_147348828_RC2PNK9V0AFY_RTRMADP_3_BERKSHIRE-BUFFETT-e1609937540903.jpg?quality=75&strip=all&w=1200&h=630&crop=1',
#    'publishedAt': '2021-01-06T17:48:15Z',
#    'content': 'So the CEOs of Amazon, Berkshire Hathaway, and JPMorgan Chase walked into largest and least efficient healthcare market in the world with a plan to disrupt itand failed to do so.\r\nHaven, the nonprofi… [+6626 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Jack Kelly, Senior Contributor, \n Jack Kelly, Senior Contributor\n https://www.forbes.com/sites/jackkelly/',
#    'title': 'Here Are Fast-Growing Jobs For The Future',
#    'description': 'As the American population gets older and technology continues to dominate, there will be a plethora of new, exciting and high-paying opportunities in these sectors.',
#    'url': 'https://www.forbes.com/sites/jackkelly/2021/01/11/here-are-fast-growing-jobs-for-the-future/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5ffc72c7682574d2d2470df5%2F0x0.jpg',
#    'publishedAt': '2021-01-11T15:53:16Z',
#    'content': '(Photo by Arthur Elgort/Conde Nast via Getty Images)\r\nContour by Getty Images\r\nThere are fast-growing trends that will shape the future of jobs. The Wall Street Journal predictsbased upon its researc… [+5046 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Michelle Marchante',
#    'title': 'Florida will get the Moderna vaccine soon. Who can get it, where and how?',
#    'description': 'Florida is preparing to send a shipment of Moderna’s COVID-19 vaccine to 173 hospitals across the state soon, including in South Florida.',
#    'url': 'https://news.yahoo.com/florida-moderna-vaccine-soon-where-151753338.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/3qKo5vo7Ha0eh7ivHyU5bg--~B/aD03NjA7dz0xMTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/miami_herald_mcclatchy_975/1f3ae75d5e7417aa6b246eda1f88cc4a',
#    'publishedAt': '2020-12-21T15:17:53Z',
#    'content': 'Florida is preparing to send a shipment of Modernas COVID-19 vaccine to 173 hospitals across the state soon, including in South Florida.\r\nHospitals expected to receive the Moderna vaccine include Bap… [+7469 chars]'},
#   {'source': {'id': None, 'name': 'TheStreet'},
#    'author': 'Stephen Guilfoyle',
#    'title': 'Best Healthcare Stocks to Buy for 2021',
#    'description': 'Real Money contributor Stephen Guilfoyle checks which healthcare sector names could perform best over the coming year.',
#    'url': 'https://www.thestreet.com/investing/best-healthcare-stocks-to-buy-for-2021',
#    'urlToImage': 'https://www.thestreet.com/.image/t_share/MTczNjA5ODAwODk3NTM3NjQ0/kangji-medical-investor-sees-more-health-care-start-ups-opting-for-a-hong-kong-listing.jpg',
#    'publishedAt': '2020-12-29T15:15:00Z',
#    'content': "I'm going to recommend healthcare stocks for your portfolio in 2021, but first let's check the sector's vitals.\r\nUsing the exchange-traded fund Health Care Sector Select SPDR\xa0 (XLV) - Get Report\xa0as a… [+9812 chars]"},
#   {'source': {'id': None, 'name': 'Seeking Alpha'},
#    'author': 'Khen Elazar',
#    'title': 'Roche Is A Suitable Addition To Diversified Dividend Growth Portfolios',
#    'description': 'I was looking at the healthcare sector for ideas lately. After I analyzed Abbott and Owens & Minor, I decided to go international.',
#    'url': 'https://seekingalpha.com/article/4395846-roche-is-suitable-addition-to-diversified-dividend-growth-portfolios',
#    'urlToImage': 'https://static1.seekingalpha.com/uploads/2020/12/22/20475971-1608652638733135.png',
#    'publishedAt': '2020-12-22T19:32:55Z',
#    'content': 'Introduction\r\nThe healthcare sector gets plenty of attention lately in the media, and among many Seeking Alpha authors, myself included. Covid-19 is still the largest single event to affect our econo… [+7229 chars]'}]}

# %%
# Fetch the XLE - Energy Sector news articles
energy_headlines = newsapi.get_everything(q="American Energy Sector" or "XOM" or "Exxon Mobil" or "CVX" or "Chevron" or "PSX" or "SLB" or "Schlumberger" or "COP" or "ConcoPhillips" or "Phillips 66" or "EOG" or "EOG Resources" or "MPC" or "Marathon Petrolem" or "KMI" or "Kinder Morgan Inc" or "WMB" or "Willliams Companies Inc" or "VLO" or "Valero Energy Corp",
                                           language="en",
                                           sort_by="relevancy")
energy_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 1147,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Mariella Moon',
#    'title': 'FAA approves first commercial drone flights with no on-site pilots',
#    'description': 'Farms and other agricultural operations in certain rural areas in the US can now use robotic drones to take images of or gather data on their crops. The FAA has approved Massachusetts-based American Robotics’ request to be able to deploy automated drones with…',
#    'url': 'https://www.engadget.com/faa-approves-first-commercial-automated-drone-flights-192554778.html',
#    'urlToImage': 'https://o.aolcdn.com/images/dims?resize=1200%2C630&crop=1200%2C630%2C0%2C0&quality=95&image_uri=https%3A%2F%2Fs.yimg.com%2Fos%2Fcreatr-uploaded-images%2F2021-01%2F0c302c50-5825-11eb-9f9b-a5564cb624af&client=amp-blogside-v2&signature=47264f60bf9ce4d37e98148f2699ef455901c997',
#    'publishedAt': '2021-01-16T19:25:54Z',
#    'content': 'The company won the FAA’s trust by testing its technology for four years across eight states — last year, it flew as many as 10 autonomous flights a day to capture agriculture imagery and other data.… [+1090 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Esme Nicholson',
#    'title': "'Trump Has Created A Huge Chasm' In U.S. Society: Capitol Siege Viewed From Berlin",
#    'description': 'The violent insurrection attempt at the U.S. Capitol stunned many in Germany, especially those who grew up in the American sector of then-West Berlin.',
#    'url': 'https://www.npr.org/2021/01/12/955616355/trump-has-created-a-huge-chasm-in-u-s-society-capitol-siege-viewed-from-berlin',
#    'urlToImage': 'https://media.npr.org/assets/img/2021/01/11/ap_619462414231_wide-5cd40a0581ffd18d8029c2d184d29d990549b4c5.jpg?s=1400',
#    'publishedAt': '2021-01-12T18:45:37Z',
#    'content': 'A group of former displaced persons helps to load the Freedom Bell aboard a Navy transport vessel in Brooklyn, New York, Oct. 9, 1950. One of the children, Eva Zandler, 8, originally from Poland, pre… [+7981 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Walter Thompson',
#    'title': 'Inadequate federal privacy regulations leave US startups lagging behind Europe',
#    'description': 'I believe startups in the United States should be demanding that legislators deliver a federal privacy law.',
#    'url': 'http://techcrunch.com/2021/01/11/inadequate-federal-privacy-regulations-leave-us-startups-lagging-behind-europe/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2021/01/GettyImages-172878844.jpg?w=598',
#    'publishedAt': '2021-01-11T16:35:22Z',
#    'content': 'A new law to follow seems unlikely to have featured on many business wishlists this holiday season, particularly if that law concerned data privacy. Digital privacy management is an area that takes c… [+5919 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Alire Garcia',
#    'title': 'Outgoing U.S. officials slam Mexican energy policy for bias - Reuters',
#    'description': 'A letter signed by three of outgoing President Donald Trump\'s top officials sharply criticizes the Mexican government\'s energy policies for what it describes as damaging the "investment climate" in the country due to bias against private companies.',
#    'url': 'https://www.reuters.com/article/usa-mexico-energy/outgoing-us-officials-slam-mexican-energy-policy-for-bias-idUSL1N2JQ1TO',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210115&t=2&i=1547958965&r=LYNXMPEH0E1AR&w=800',
#    'publishedAt': '2021-01-15T17:40:00Z',
#    'content': "FILE PHOTO: Mexico's Energy Minister Rocio Nahle attends a news conference at the National Palace in Mexico City, Mexico, December 9, 2019. REUTERS/Edgard Garrido\r\nMEXICO CITY (Reuters) - A letter si… [+2065 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Sudip Kar-Gupta',
#    'title': 'Total speeds up renewables push with $2.5 billion investment in Indian solar power - Reuters.com',
#    'description': "Total is paying $2.5 billion for a share in Indian renewable energy firm Adani Green Energy Limited (AGEL) and a portfolio of solar power assets, marking the latest step in the French energy company's drive to reduce its dependence on oil.",
#    'url': 'https://www.reuters.com/article/marketsNews/idUSL1N2JT0AK?il=0',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210118&t=2&i=1548165325&r=LYNXMPEH0H05M&w=800',
#    'publishedAt': '2021-01-18T09:59:58Z',
#    'content': 'PARIS (Reuters) - Total is paying $2.5 billion for a share in Indian renewable energy firm Adani Green Energy Limited (AGEL) and a portfolio of solar power assets, marking the latest step in the Fren… [+2044 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Steve Scherer',
#    'title': "Silver lining: Biden's scrapping of Keystone pipeline allows Canada's Trudeau to move on - Reuters",
#    'description': "U.S. President Joe Biden's move to scrap the Keystone XL oil pipeline, while a blow to Canada's energy sector, is a blessing in disguise for Prime Minister Justin Trudeau, who is eager to embrace the new administration, two sources familiar with the matter sa…",
#    'url': 'https://www.reuters.com/article/us-usa-biden-keystone-trudeau-idUSKBN29P2K4',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210120&t=2&i=1548482952&r=LYNXMPEH0J1G4&w=800',
#    'publishedAt': '2021-01-20T18:53:00Z',
#    'content': 'OTTAWA (Reuters) - U.S. President Joe Bidens move to scrap the Keystone XL oil pipeline, while a blow to Canadas energy sector, is a blessing in disguise for Prime Minister Justin Trudeau, who is eag… [+2972 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Rod Nickel, Nia Williams',
#    'title': 'Biden to revoke Keystone XL pipeline permit after swearing-in: aides - Reuters',
#    'description': "U.S. President-elect Joe Biden on Wednesday will revoke the permit needed to build the Keystone XL oil pipeline after being sworn into office, aides said, dashing Ottawa's hopes of salvaging a project that the struggling Canadian crude sector has long support…",
#    'url': 'https://www.reuters.com/article/us-usa-biden-keystone-idUSKBN29P1RZ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210120&t=2&i=1548454257&r=LYNXMPEH0J0YD&w=800',
#    'publishedAt': '2021-01-20T15:12:43Z',
#    'content': 'CALGARY, Alberta (Reuters) - U.S. President-elect Joe Biden on Wednesday will revoke the permit needed to build the Keystone XL oil pipeline after being sworn into office, aides said, dashing Ottawas… [+2433 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Dave Graham',
#    'title': "Analysis: Mexican president's energy reform threat faces U.S. reality check - Reuters",
#    'description': "Mexico's government is coming to realize that with a new president entering the White House on Wednesday, overturning a reform that opened Mexican energy markets to foreign investors might not be as straightforward as it thought.",
#    'url': 'https://www.reuters.com/article/mexico-usa-energy/analysis-mexican-presidents-energy-reform-threat-faces-us-reality-check-idUSL1N2J6094',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210119&t=2&i=1548343144&r=LYNXMPEH0I1E2&w=800',
#    'publishedAt': '2021-01-19T18:32:00Z',
#    'content': 'MEXICO CITY (Reuters) - Mexicos government is coming to realize that with a new president entering the White House on Wednesday, overturning a reform that opened Mexican energy markets to foreign inv… [+5169 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Marley Jay',
#    'title': 'Buy these 30 stocks that handily beat the market in 2020 and are poised for the best global returns in 2021, RBC says',
#    'description': "Summary List PlacementPredicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\nA group of RBC's top stock researchers are taking their shot once again by updating their list of 30 to…",
#    'url': 'https://www.businessinsider.com/stock-picks-to-buy-in-2021-market-rbc-top-recommendations-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff4861d6056b60018721f18?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T16:01:00Z',
#    'content': "Predicting what's going to happen in 2021 takes some nerve after all the surprising twists of last year, but the experts have to try.\r\nA group of RBC's top stock researchers are taking their shot onc… [+1463 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'CANADA STOCKS-TSX rises on boost from pot stocks, U.S. stimulus bets - Reuters',
#    'description': "Canada's main stock index rose on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took control of the Senate.",
#    'url': 'https://www.reuters.com/article/canada-stocks-idUSL4N2JI314',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T15:28:00Z',
#    'content': 'By Reuters Staff\r\nJan 7 (Reuters) - Canadas main stock index rose on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took… [+1777 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 2-CANADA STOCKS-TSX hits record high on boost from pot stocks, U.S. stimulus bets - Reuters',
#    'description': "Canada's main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took control of the Senate.",
#    'url': 'https://www.reuters.com/article/canada-stocks-idUSL4N2JI3A3',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T16:28:00Z',
#    'content': 'By Reuters Staff\r\n(Updates prices to add milestone)\r\nJan 7 (Reuters) - Canadas main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an ex… [+1828 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'UPDATE 2-CANADA STOCKS-TSX hits record high on boost from pot stocks, U.S. stimulus bets - Reuters UK',
#    'description': "Canada's main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an extended U.S. stimulus package to aid economic recovery after Democrats took control of the Senate.",
#    'url': 'https://uk.reuters.com/article/canada-stocks-idUKL4N2JI3A3',
#    'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#    'publishedAt': '2021-01-07T16:25:00Z',
#    'content': 'By Reuters Staff\r\n(Updates prices to add milestone)\r\nJan 7 (Reuters) - Canadas main stock index rose to a record high in late morning trade on Thursday, boosted by cannabis stocks and hopes for an ex… [+1828 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Maiya Keidan, Rod Nickel',
#    'title': 'Hedge funds bet on recovery in 2021 - Reuters',
#    'description': 'Some global hedge fund investors are going into 2021 optimistic about a speedy snap-back from the economic challenges related to the coronavirus pandemic.',
#    'url': 'https://www.reuters.com/article/us-health-coronavirus-hedgefunds-yearend-idUSKBN2990IJ',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210104&t=2&i=1546505590&r=LYNXMPEH0308H&w=800',
#    'publishedAt': '2021-01-04T06:00:00Z',
#    'content': 'TORONTO (Reuters) - Some global hedge fund investors are going into 2021 optimistic about a speedy snap-back from the economic challenges related to the coronavirus pandemic.\r\nFILE PHOTO: George Wash… [+3958 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Theo Golden',
#    'title': 'GOLDMAN SACHS: Buy these 50 under-owned stocks that will roar higher as growth and inflation lift off in 2021',
#    'description': 'Summary List PlacementValue stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourth quarter of 2020.\nEven with at least …',
#    'url': 'https://www.businessinsider.com/stocks-to-buy-50-under-owned-recovery-value-goldman-sachs-2021-1',
#    'urlToImage': 'https://i.insider.com/5ffd9844bde805001980c54d?width=1200&format=jpeg',
#    'publishedAt': '2021-01-12T15:18:24Z',
#    'content': 'Value stocks are set to outperform in 2021, as global economic activity recovers and inflation expectations pick up, continuing the historic rotation away from growth stocks that started in the fourt… [+4716 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Nia Williams',
#    'title': "UPDATE 1-Canada's Alberta urges Trudeau to press Biden, save Keystone XL pipeline - Reuters",
#    'description': "Canada's main oil-producing province Alberta urged Prime Minister Justin Trudeau on Monday to mount a last-ditch effort to save an $8 billion pipeline and threatened to seek damages if U.S. President-elect Joe Biden cancels Keystone XL.",
#    'url': 'https://www.reuters.com/article/usa-biden-keystone/update-1-canadas-alberta-urges-trudeau-to-press-biden-save-keystone-xl-pipeline-idUSL1N2JT1GB',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210118&t=2&i=1548214793&r=LYNXMPEH0H0ZX&w=800',
#    'publishedAt': '2021-01-18T18:32:00Z',
#    'content': 'CALGARY, Alberta (Reuters) - Canadas main oil-producing province Alberta urged Prime Minister Justin Trudeau on Monday to mount a last-ditch effort to save an $8 billion pipeline and threatened to se… [+3266 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Nicole Kobie, WIRED UK',
#    'title': '20 Things That Made the World a Better Place in 2020',
#    'description': 'From record-beating scientific discoveries to an elephant baby boom, this year was about much more than just a global pandemic.',
#    'url': 'https://www.wired.com/story/20-things-world-better-place-2020/',
#    'urlToImage': 'https://media.wired.com/photos/5fe429ef6a4c22d9a3277a00/191:100/w_1280,c_limit/Science_2021_1230196314.jpg',
#    'publishedAt': '2020-12-30T14:00:00Z',
#    'content': "This story originally appeared on WIRED UK.\r\nThis is not a year we'll look back on fondly. It began with Australia on fire and ends with more than 1.5 million dead in a pandemic. But there have been … [+9068 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Devik Jain, Supriya R',
#    'title': 'US STOCKS-S&P, Nasdaq futures at record levels as Trump signs stimulus aid bill - Reuters',
#    'description': "Futures tracking the S&P 500 and the Nasdaq were at record levels on Monday as President Donald Trump's move to sign into law a long-awaited $2.3 trillion pandemic aid bill bolstered bets on a vaccine-led economic recovery.",
#    'url': 'https://www.reuters.com/article/us-usa-stocks-idUSKBN292101',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201228&t=2&i=1545959094&r=LYNXMPEGBR0GQ&w=800',
#    'publishedAt': '2020-12-28T12:30:00Z',
#    'content': '(Reuters) - Futures tracking the S&amp;P 500 and the Nasdaq were at record levels on Monday as President Donald Trumps move to sign into law a long-awaited $2.3 trillion pandemic aid bill bolstered b… [+2220 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bracing for Biden climate rules, U.S. Chamber asks Congress to make laws - Reuters',
#    'description': "The U.S. Chamber of Commerce, the country's biggest and most influential business lobby group, shifted its position on climate change on Tuesday, saying Congress should pass laws pushing companies to limit greenhouse gas emissions.",
#    'url': 'https://www.reuters.com/article/us-usa-climate-business-idUSKBN29O2JN',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210119&t=2&i=1548359876&r=LYNXMPEH0I1JM&w=800',
#    'publishedAt': '2021-01-19T21:06:00Z',
#    'content': 'By Reuters Staff\r\nWASHINGTON (Reuters) - The U.S. Chamber of Commerce, the countrys biggest and most influential business lobby group, shifted its position on climate change on Tuesday, saying Congre… [+2073 chars]'},
#   {'source': {'id': None, 'name': 'Ctvnews.ca'},
#    'author': 'CTV News Calgary',
#    'title': "Kenney calls Biden's Keystone XL cancellation 'gut punch' to Albertans - CTV Toronto",
#    'description': "<ol><li>Kenney calls Biden's Keystone XL cancellation 'gut punch' to Albertans\xa0\xa0CTV Toronto\r\n</li><li>Biden revokes presidential permit for Keystone XL pipeline expansion on 1st day\xa0\xa0Global News\r\n</li><li>Alberta premier suggests Canada impose trade sanctions…",
#    'url': 'https://calgary.ctvnews.ca/kenney-calls-biden-s-keystone-xl-cancellation-gut-punch-to-albertans-1.5274690',
#    'urlToImage': 'https://www.ctvnews.ca/polopoly_fs/1.5112497.1600625944!/httpImage/image.jpg_gen/derivatives/landscape_620/image.jpg',
#    'publishedAt': '2021-01-21T01:40:00Z',
#    'content': "CALGARY -- \r\nAlberta Premier Jason Kenney described the cancellation of Keystone XL's permit as a 'gut punch' and 'insult' to Albertans Wednesday.\r\nBiden's Day 1 actions as the new American president… [+4151 chars]"},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Alicja Siekierska',
#    'title': 'WestJet unveils plan to return Boeing 737 Max to service - Yahoo Canada Finance',
#    'description': "<ol><li>WestJet unveils plan to return Boeing 737 Max to service\xa0\xa0Yahoo Canada Finance\r\n</li><li>WestJet's 737 MAX: Behind the Scenes\xa0\xa0WestJet\r\n</li><li>WestJet planning to fly 737 Max jets this month, pending Transport Canada OK\xa0\xa0CBC.ca\r\n</li><li>American Ai…",
#    'url': 'https://ca.finance.yahoo.com/news/west-jet-unveils-plan-to-return-boeing-737-max-to-service-162259556.html',
#    'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/tI_xwO7TakW1cn_dBmZmzQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTIwMDA7aD0xMzMz/https://s.yimg.com/os/creatr-uploaded-images/2021-01/688da290-503a-11eb-ba76-a1cc60ac2d96',
#    'publishedAt': '2021-01-06T16:22:00Z',
#    'content': '(Bloomberg) -- Following are the minutes of the Federal Reserves Open Market Committee meeting on Dec. 16:A joint meeting of the Federal Open Market Committee and the Board of Governors was held by v… [+50172 chars]'}]}

# %%
# Fetch the ETH - Ethereum news articles
ethereum_headlines = newsapi.get_everything(q="ethereum",
                                           language="en",
                                           sort_by="relevancy")
ethereum_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 1452,
#  'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': "Ripple Claims Bitcoin Is 'Chinese-Controlled' While Announcing New Lawsuit From SEC",
#    'description': 'The Securities and Exchange Commission plans to sue Ripple in federal civil court for selling unregistered securities, according to a news release published online by the cryptocurrency company late Monday. Ripple defended its cryptocurrency, known as XRP, as…',
#    'url': 'https://gizmodo.com/ripple-claims-bitcoin-is-chinese-controlled-while-annou-1845932148',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/ahh1hzpmuhrh8ybwimab.jpg',
#    'publishedAt': '2020-12-22T11:30:00Z',
#    'content': 'The Securities and Exchange Commission plans to sue Ripple in federal civil court for selling unregistered securities, according to a news release published online by the cryptocurrency company late … [+2950 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'William Edwards',
#    'title': "A crypto CEO breaks down why he would not be surprised to see Bitcoin and Ethereum rise at least 100% in 2021 — and says the current sell-offs are a 'very natural and healthy thing'",
#    'description': 'Summary List PlacementCryptocurrencies stole headlines on the first stock-market trading day of 2021, with bitcoin and ethereum selling off steeply after blistering run-ups over the weekend.\nBut investors need not worry about too sharp of a drop in the digita…',
#    'url': 'https://www.businessinsider.com/bitcoin-ethereum-price-forecasts-2021-upside-greg-king-osprey-funds-2021-1',
#    'urlToImage': 'https://i.insider.com/5ff381b76056b60018721d74?width=1200&format=jpeg',
#    'publishedAt': '2021-01-05T13:15:00Z',
#    'content': 'Cryptocurrencies stole headlines on the first stock-market trading day of 2021, with bitcoin and ethereum selling off steeply after blistering run-ups over the weekend.\r\nBut investors need not worry … [+2877 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Gertrude Chavez-Dreyfuss',
#    'title': 'Total crypto fund inflows top $5 billion this year, up more than 600% - report - Reuters',
#    'description': 'Total investor inflows into cryptocurrency funds and products hit $5.6 billion so far this year, up more than 600% from 2019, according to the latest data from asset manager CoinShares.',
#    'url': 'https://www.reuters.com/article/us-crypto-currencies-flows-idUSKBN28V2OE',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545352030&r=LYNXMPEGBK1H1&w=800',
#    'publishedAt': '2020-12-21T20:17:00Z',
#    'content': 'NEW YORK (Reuters) - Total investor inflows into cryptocurrency funds and products hit $5.6 billion so far this year, up more than 600% from 2019, according to the latest data from asset manager Coin… [+2077 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Ether soars above $1,000 in broad cryptocurrency rally',
#    'description': 'The value of all cryptocurrencies in circulation is more than $850 billion.',
#    'url': 'https://arstechnica.com/tech-policy/2021/01/ether-soars-above-1000-in-broad-cryptocurrency-rally/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2017/11/36490685544_09623d813d_z-640x380.jpg',
#    'publishedAt': '2021-01-04T17:08:27Z',
#    'content': 'Ethereum creator Vitalik Buterin.\r\n14 with 11 posters participating\r\nEther, the native currency of the Ethereum network and the second most valuable cryptocurrency, has soared above $1,000 for the fi… [+3015 chars]'},
#   {'source': {'id': None, 'name': 'BNNBloomberg.ca'},
#    'author': 'Bloomberg News',
#    'title': 'Bitcoin rally comes to a halt as prices fall most since March - BNN',
#    'description': '<ol><li>Bitcoin rally comes to a halt as prices fall most since March\xa0\xa0BNN\r\n</li><li>Bitcoin, Ethereum Outlook: Cryptos Go Parabolic, is a Correction Due?\xa0\xa0DailyFX\r\n</li><li>Bitcoin slumps, slamming brakes on New Year rally\xa0\xa0The Globe and Mail\r\n</li><li>Bitco…',
#    'url': 'http://www.bnnbloomberg.ca/bitcoin-mania-reaches-new-heights-as-prices-go-parabolic-1.1543469',
#    'urlToImage': 'http://www.bnnbloomberg.ca/polopoly_fs/1.1468795!/fileimage/httpImage/image.jpg_gen/derivatives/landscape_620/bitcoin.jpg',
#    'publishedAt': '2021-01-04T13:58:21Z',
#    'content': 'Bitcoin fizzled in Monday trading as the famously volatile cryptocurrency pulled back after a spectacular new-year rally.\r\nPrices fell as much as 17 per cent in the biggest drop since March before re… [+2174 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin falls 5% to $37507 on Bitstamp exchange - Reuters',
#    'description': 'Bitcoin fell more than 5% on Friday, a day after topping $40,000 for the first time.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency/bitcoin-falls-5-to-37507-on-bitstamp-exchange-idUSKBN29D0BF?feedType=mktg&feedName=ousivMolt&WT.mc_id=Partner-Google',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210108&t=2&i=1547047065&r=LYNXMPEH07049&w=800',
#    'publishedAt': '2021-01-08T02:48:37Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency bitcoin is seen in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\r\nTOKYO (Reuters) - Bitcoin fell more t… [+293 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin falls 5% to $37507 on Bitstamp exchange - Reuters',
#    'description': 'Bitcoin fell more than 5% on Friday, a day after topping $40,000 for the first time.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency/bitcoin-falls-5-to-37507-on-bitstamp-exchange-idUSKBN29D0BF',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210108&t=2&i=1547047978&r=LYNXMPEH0704I&w=800',
#    'publishedAt': '2021-01-08T02:51:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency bitcoin is seen in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\r\nTOKYO (Reuters) - Bitcoin fell more t… [+293 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits one-week low as rising U.S. yields dent rally - Reuters',
#    'description': 'Cryptocurrencies plunged on Monday, with bitcoin dropping more than 12% to a one-week low as rising U.S. yields lifted the dollar broadly and hurt non-income paying assets.',
#    'url': 'https://www.reuters.com/article/crypto-currency/bitcoin-hits-one-week-low-as-rising-us-yields-dent-rally-idUSL4N2JM0QA',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210111&t=2&i=1547318703&r=LYNXMPEH0A04G&w=800',
#    'publishedAt': '2021-01-11T03:57:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and small toy figures are placed on computer motherboard in this illustration taken January 7, 2021. REUTERS/Dado Ruvic\r\nSIN… [+351 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Bitcoin hits one-week low as rising U.S. yields dent rally - Reuters',
#    'description': 'Cryptocurrencies plunged on Monday, with bitcoin dropping more than 12% to a one-week low as rising U.S. yields lifted the dollar broadly and hurt non-income paying assets.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency/bitcoin-hits-one-week-low-as-rising-u-s-yields-dent-rally-idUSKBN29G08M',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210111&t=2&i=1547318703&r=LYNXMPEH0A04G&w=800',
#    'publishedAt': '2021-01-11T03:57:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: A representation of virtual currency Bitcoin and small toy figures are placed on computer motherboard in this illustration taken January 7, 2021. REUTERS/Dado Ruvic\r\nSIN… [+351 chars]'},
#   {'source': {'id': None, 'name': 'PC Gamer'},
#    'author': 'Paul Lilly',
#    'title': 'This crypto-mining farm with 78 GeForce RTX 3080 GPUs likely rakes in $154,000 per year - PC Gamer',
#    'description': '<ol><li>This crypto-mining farm with 78 GeForce RTX 3080 GPUs likely rakes in $154,000 per year\xa0\xa0PC Gamer\r\n</li><li>Nvidia RTX 3080 is apparently coming to the most powerful gaming laptops\xa0\xa0TechRadar\r\n</li><li>MSI GeForce RTX 3080 SUPRIM X Review: Big, Bad An…',
#    'url': 'https://www.pcgamer.com/this-crypto-mining-farm-with-78-geforce-rtx-3080-gpus-likely-rakes-in-dollar154000-per-year/',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/rf9THsLa9ej546K8fw64wC-1200-80.jpg',
#    'publishedAt': '2020-12-31T13:13:00Z',
#    'content': 'It seems only fitting to end 2020 on a depressing note, and to that end, a cryptocurrency miner living in Las Vegas has apparently managed to procure dozens of PNY brand GeForce RTX 3080 cards to min… [+3181 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Sequoia Holdings says employees can draw part of salary in cryptocurrencies - Reuters',
#    'description': 'Software development services provider Sequoia Holdings LLC said on Thursday its employees can now receive a part of their salary in cryptocurrencies, should they choose to.',
#    'url': 'https://www.reuters.com/article/us-sequoia-holdings-salary-bitcoin-idUSKBN29Q21G',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210121&t=2&i=1548594098&r=LYNXMPEH0K13S&w=800',
#    'publishedAt': '2021-01-21T14:53:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic/Illustration\r\n(Reuters) - Software devel… [+676 chars]'},
#   {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#    'author': None,
#    'title': 'Bitcoin Holds Near Record, Ether Surges Amid Crypto Rally - Bloomberg',
#    'description': '<ol><li>Bitcoin Holds Near Record, Ether Surges Amid Crypto Rally\xa0\xa0Bloomberg\r\n</li><li>Bitcoin price passes new milestone of US$ 34000\xa0\xa0Arirang News\r\n</li><li>Ethereum Breaks Past $900 As Altcoins Go Nuts\xa0\xa0Decrypt\r\n</li><li>Bitcoin Blasts Past $34K for First …',
#    'url': 'https://www.bloomberg.com/tosv2.html?vid=&uuid=9ec43210-4e6a-11eb-b641-572cf808966a&url=L25ld3MvYXJ0aWNsZXMvMjAyMS0wMS0wNC9ldGhlci1mb2xsb3dzLWJpdGNvaW4tdG8tcmVjb3JkLWhpZ2gtYW1pZC1kaXp6eWluZy1jcnlwdG8tcmFsbHk=',
#    'urlToImage': None,
#    'publishedAt': '2021-01-04T01:44:00Z',
#    'content': None},
#   {'source': {'id': None, 'name': 'Sagivo.com'},
#    'author': None,
#    'title': 'Make passive income using Ethereum 2.0',
#    'description': 'Learn how to become eth2 validator and earn staking fees',
#    'url': 'https://sagivo.com/crypto/2020/12/26/Etherum2.0.html',
#    'urlToImage': None,
#    'publishedAt': '2020-12-26T22:35:05Z',
#    'content': 'Ethereum is one of the leading crypto projects (second to bitcoin). In December 2020 Ethereum released the first stage of Ethereum 2.0. The biggest difference is that there is no need for an expensiv… [+12510 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Sarah Austin',
#    'title': "How 2020 Became the Year of DeFi and What's to Come in 2021",
#    'description': 'What will be the biggest trend in 2021? Decentralized finance is geared up to be the biggest thing since Bitcoin.',
#    'url': 'https://www.entrepreneur.com/article/362319',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1610032210-GettyImages-1277771766.jpg',
#    'publishedAt': '2021-01-09T19:15:00Z',
#    'content': 'January\r\n9, 2021\r\n7 min read\r\nOpinions expressed by Entrepreneur contributors are their own.\r\nFor the blockchain sector, 2020 was the year of decentralized finance. While the rest of the world was gr… [+7394 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Tom Wilson',
#    'title': 'Bitcoin slumps 6% as new COVID-19 strain upsets wider markets - Reuters UK',
#    'description': 'Bitcoin dropped as much as 6% on Monday, with fears over a fast-spreading new coronavirus strain in Britain hitting assets across wider markets.',
#    'url': 'https://www.reuters.com/article/uk-crypto-currency-idUKKBN28V1J5',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201221&t=2&i=1545299228&r=LYNXMPEGBK0VH&w=800',
#    'publishedAt': '2020-12-21T12:50:00Z',
#    'content': 'FILE PHOTO: A representation of virtual currency Bitcoin is seen in this illustration taken November 19, 2020. REUTERS/Dado Ruvic/Illustration\r\nLONDON (Reuters) - Bitcoin dropped as much as 6% on Mon… [+1263 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Tom Wilson',
#    'title': 'Bitcoin jumps to record $28,600 as 2020 rally reaches new heights - Reuters India',
#    'description': 'Bitcoin on Wednesday jumped to a record $28,599.99, after the digital currency almost quadrupled in value this year amid heightened interest from bigger investors.',
#    'url': 'https://in.reuters.com/article/us-crypto-currency-idINKBN2940X0',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201230&t=2&i=1546143610&r=LYNXMPEGBT0H5&w=800',
#    'publishedAt': '2020-12-30T10:56:00Z',
#    'content': 'LONDON (Reuters) - Bitcoin on Wednesday jumped to a record $28,599.99, after the digital currency almost quadrupled in value this year amid heightened interest from bigger investors.\r\nThe worlds most… [+1092 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'David Randall',
#    'title': "Big tech bets and cryptocurrencies power 2020's top U.S. funds - Reuters Africa",
#    'description': "Outsized bets on large U.S. technology companies and emerging cryptocurrencies fueled the year's top-performing U.S. mutual fund and exchange-traded funds as the coronavirus pandemic upended global markets, while funds that bet on oil and gas companies fell n…",
#    'url': 'https://www.reuters.com/article/us-usa-funds-sectors-yearend-idUSKBN2920CG',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201228&t=2&i=1545935468&r=LYNXMPEGBR05A&w=800',
#    'publishedAt': '2020-12-28T06:07:00Z',
#    'content': 'NEW YORK (Reuters) - Outsized bets on large U.S. technology companies and emerging cryptocurrencies fueled the years top-performing U.S. mutual fund and exchange-traded funds as the coronavirus pande… [+3726 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'The world’s cryptocurrency is now worth more than $1 trillion',
#    'description': "Bitcoin's anonymous founder, Satoshi Nakamoto, could be worth $40 billion.",
#    'url': 'https://arstechnica.com/tech-policy/2021/01/the-worlds-cryptocurrency-is-now-worth-more-than-1-trillion/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2014/11/bitcoin-640x215.jpg',
#    'publishedAt': '2021-01-07T17:30:27Z',
#    'content': "1 with 1 posters participating\r\nThe world's cryptocurrency is now worth more than $1 trillion, with bitcoin accounting for a large majority of the value. The price of the oldest virtual currency has … [+1174 chars]"},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'StackSocial',
#    'title': 'Become an expert cryptocurrency investor with this bundle of six courses for $30',
#    'description': 'Source: StackCommerce\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cryptocurrency Professional Trading Bundle\xa0shows you how to rid…',
#    'url': 'https://www.androidcentral.com/become-expert-cryptocurrency-investor-bundle-six-courses-30',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/field/image/2020/12/sale_159885_article_image-2nqh.jpg',
#    'publishedAt': '2020-12-27T18:03:02Z',
#    'content': 'Source: StackCommerce\r\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cr… [+1002 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Crypto trading volumes hit record $68.3 billion on Monday - CryptoCompare - Reuters UK',
#    'description': "Trading volumes on major cryptocurrency exchanges hit a daily record on Monday of over $68 billion, research showed, highlighting the trading frenzy that has accompanied bitcoin's charge to an all-time high.",
#    'url': 'https://www.reuters.com/article/us-crypto-currency-idUKKBN29A1N6',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20210105&t=2&i=1546668985&r=LYNXMPEH040V2&w=800',
#    'publishedAt': '2021-01-05T14:43:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of virtual currency Bitcoin are seen in this picture illustration taken taken March 13, 2020. REUTERS/Dado Ruvic\r\nLONDON (Reuters) - Trading volumes on m… [+1327 chars]'}]}

# %%
# Fetch the LTC - Litecoin news articles
lite_headlines = newsapi.get_everything(q="litecoin",
                                        language="en",
                                        sort_by="relevancy")
lite_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 348,
#  'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Cryptocurrency XRP drops 18% after U.S. SEC charges Ripple over offering - Reuters India',
#    'description': 'Cryptocurrency XRP tumbled 18% to a one-month low on Wednesday after the U.S. Securities and Exchange Commission (SEC) charged associated blockchain firm Ripple with conducting a $1.3 billion unregistered securities offering.',
#    'url': 'https://in.reuters.com/article/us-crypto-currency-ripple-idINKBN28X116',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201223&t=2&i=1545538377&r=LYNXMPEGBM0JQ&w=800',
#    'publishedAt': '2020-12-23T09:22:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+301 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Cryptocurrency XRP drops 18% after U.S. SEC charges Ripple over offering - Reuters',
#    'description': 'Cryptocurrency XRP tumbled 18% to a one-month low on Wednesday after the U.S. Securities and Exchange Commission (SEC) charged associated blockchain firm Ripple with conducting a $1.3 billion unregistered securities offering.',
#    'url': 'https://www.reuters.com/article/us-crypto-currency-ripple-idUSKBN28X116',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201223&t=2&i=1545538377&r=LYNXMPEGBM0JQ&w=800',
#    'publishedAt': '2020-12-23T09:23:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+301 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'XRP cryptocurrency slumps 16% as Coinbase exchange moves to suspend trading - Reuters UK',
#    'description': 'Cryptocurrency XRP slumped 16% on Tuesday after major U.S. virtual coin exchange Coinbase said it would suspend trading in the digital currency.',
#    'url': 'https://uk.reuters.com/article/uk-crypto-currency-idUKKBN2930WX',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201229&t=2&i=1546042928&r=LYNXMPEGBS0GK&w=800',
#    'publishedAt': '2020-12-29T11:25:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+623 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'The world’s cryptocurrency is now worth more than $1 trillion',
#    'description': "Bitcoin's anonymous founder, Satoshi Nakamoto, could be worth $40 billion.",
#    'url': 'https://arstechnica.com/tech-policy/2021/01/the-worlds-cryptocurrency-is-now-worth-more-than-1-trillion/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2014/11/bitcoin-640x215.jpg',
#    'publishedAt': '2021-01-07T17:30:27Z',
#    'content': "1 with 1 posters participating\r\nThe world's cryptocurrency is now worth more than $1 trillion, with bitcoin accounting for a large majority of the value. The price of the oldest virtual currency has … [+1174 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Staff',
#    'title': 'Cryptocurrency XRP tumbles 24% after U.S. SEC charges Ripple - Reuters UK',
#    'description': 'Cryptocurrency XRP <XRP=BTSP> tumbled 24% on Wednesday after the U.S. Securities and Exchange Commission (SEC) charged associated blockchain firm Ripple with conducting a $1.3 billion unregistered securities offering.',
#    'url': 'https://in.reuters.com/article/us-crypto-currency-ripple-idUKKBN28X116',
#    'urlToImage': 'https://static.reuters.com/resources/r/?m=02&d=20201223&t=2&i=1545538377&r=LYNXMPEGBM0JQ&w=800',
#    'publishedAt': '2020-12-23T09:26:00Z',
#    'content': 'By Reuters Staff\r\nFILE PHOTO: Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 14, 2018. REUTERS/Dad… [+1197 chars]'},
#   {'source': {'id': None, 'name': 'Android Central'},
#    'author': 'StackSocial',
#    'title': 'Become an expert cryptocurrency investor with this bundle of six courses for $30',
#    'description': 'Source: StackCommerce\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cryptocurrency Professional Trading Bundle\xa0shows you how to rid…',
#    'url': 'https://www.androidcentral.com/become-expert-cryptocurrency-investor-bundle-six-courses-30',
#    'urlToImage': 'https://www.androidcentral.com/sites/androidcentral.com/files/styles/large/public/field/image/2020/12/sale_159885_article_image-2nqh.jpg',
#    'publishedAt': '2020-12-27T18:03:02Z',
#    'content': 'Source: StackCommerce\r\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cr… [+1002 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Dan Whateley',
#    'title': 'Bitcoin crosses $30,000 for the first time as it charges into 2021',
#    'description': 'Summary List PlacementThe price of bitcoin crossed $30,000 for the first time on Saturday as the digital currency continued its rally into the new year.\xa0\nBitcoin reached a high of $33,136.92, a spike of around 14% over the last 24 hours.\nThe cryptocurrency ha…',
#    'url': 'https://www.businessinsider.com/bitcoin-crosses-30000-as-it-continues-to-break-records-2021-1',
#    'urlToImage': 'https://i.insider.com/5fe5e0dda6448800181935ea?width=1200&format=jpeg',
#    'publishedAt': '2021-01-02T19:46:10Z',
#    'content': 'The price of bitcoin crossed $30,000 for the first time on Saturday as the digital currency continued its rally into the new year.\xa0\r\nBitcoin reached a high of $33,136.92, a spike of around 14% over t… [+1392 chars]'},
#   {'source': {'id': None, 'name': 'Seeking Alpha'},
#    'author': None,
#    'title': 'Bit Digital leads crypto-related weakness amid short seller report - Seeking Alpha',
#    'description': 'Bit Digital (NASDAQ:BTBT) dropped 26% amidst a selloff in Bitcoin-related companies today and following a new shortseller report.Earlier, nearly $170B was wiped off cryptocurrency market in as Bitcoin (BTC-USD)\xa0dropped 20.1%\xa0to $34,130 after a huge\xa0rally and …',
#    'url': 'https://seekingalpha.com/news/3650451-bit-digital-leads-crypto-related-weakness-amid-short-seller-report',
#    'urlToImage': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#    'publishedAt': '2021-01-11T19:49:00Z',
#    'content': None},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Ether soars above $1,000 in broad cryptocurrency rally',
#    'description': 'The value of all cryptocurrencies in circulation is more than $850 billion.',
#    'url': 'https://arstechnica.com/tech-policy/2021/01/ether-soars-above-1000-in-broad-cryptocurrency-rally/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2017/11/36490685544_09623d813d_z-640x380.jpg',
#    'publishedAt': '2021-01-04T17:08:27Z',
#    'content': 'Ethereum creator Vitalik Buterin.\r\n14 with 11 posters participating\r\nEther, the native currency of the Ethereum network and the second most valuable cryptocurrency, has soared above $1,000 for the fi… [+3015 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Amanda Cooper',
#    'title': 'The Crypto Market Is Now Worth More Than $1 Trillion for the First Time as Bitcoin Hits Record Above $38,000',
#    'description': 'The entire crypto market is now worth roughly half of what Apple is and more than the entire economy of Switzerland.',
#    'url': 'https://markets.businessinsider.com/currencies/news/bitcoin-price-cryptocurrency-market-cap-apple-record-high-2021-1-1029940052',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1610031352-bitcoin.jpg',
#    'publishedAt': '2021-01-07T14:56:42Z',
#    'content': 'January\r\n7, 2021\r\n3 min read\r\nThis story originally appeared on Business InsiderThe cryptocurrency market is now worth more than $1 trillion for the first time ever after the price of bitcoin surged … [+3329 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Amanda Cooper',
#    'title': 'Bitcoin falls to a one-week low, as a stronger dollar and investor nerves strip off nearly $140 billion in total cryptocurrency market cap',
#    'description': 'Summary List PlacementCryptocurrencies tumbled on Monday, wiping off nearly $140 billion in total market cap, as traders took profits on the spectacular rally so far this month, in light of a stronger dollar and growing political uncertainty.\nInvestors will b…',
#    'url': 'https://www.businessinsider.com/bitcoin-price-dollar-rally-politics-risk-trump-impeachment-ethereum-crypto-2021-1',
#    'urlToImage': 'https://images2.markets.businessinsider.com/5ffc2e2fbde805001980c18d?format=jpeg',
#    'publishedAt': '2021-01-11T11:17:51Z',
#    'content': 'Photo illustration of visual representations of digital cryptocurrencies\r\nYuriko Nakao/Getty Images\r\nCryptocurrencies tumbled on Monday, wiping off nearly $140 billion in total market cap, as traders… [+3376 chars]'},
#   {'source': {'id': None, 'name': 'Windows Central'},
#    'author': 'StackSocial',
#    'title': 'Become an expert cryptocurrency investor with this bundle of six courses for $30',
#    'description': 'Source: StackCommerce\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cryptocurrency Professional Trading Bundle\xa0shows you how to rid…',
#    'url': 'https://www.windowscentral.com/become-expert-cryptocurrency-investor-bundle-six-courses-30',
#    'urlToImage': 'https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2020/12/sale_159885_article_image-2nqh.jpg',
#    'publishedAt': '2020-12-27T18:00:02Z',
#    'content': 'Source: StackCommerce\r\nWhen the price of Bitcoin maxed out, you might have thought the cryptocurrency bubble had burst. In fact, there are still many digital currencies gaining value.\xa0The Complete Cr… [+1002 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Barbara Kollmeyer',
#    'title': 'Cryptos: Bitcoin drops 13% after bullish start to 2021',
#    'description': 'Cryptocurrency investors were facing a rough start to the week, with bitcoin and fellow digital currencies getting hit hard by sellers.',
#    'url': 'https://www.marketwatch.com/story/bitcoin-drops-13-after-bullish-start-to-2021-11610358317',
#    'urlToImage': 'https://images.mktw.net/im-283325/social',
#    'publishedAt': '2021-01-11T09:45:00Z',
#    'content': 'What goes up must come down? Bitcoin investors may be asking themselves that question as the cryptocurrency fell sharply on Monday. The price of bitcoin \r\n BTCUSD,\r\n -6.52%\r\nwas last down 13% to $35,… [+2100 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Billy Bambrough, Contributor, \n Billy Bambrough, Contributor\n https://www.forbes.com/sites/billybambrough/',
#    'title': 'Is This Why Bitcoin, Ethereum, Litecoin And Other Cryptocurrencies Have Suddenly Shot Higher?',
#    'description': 'The bitcoin price, breaking $28,000 per bitcoin for the first time ever over the Christmas weekend, has added over 50% this month—with other major tokens ethereum and litecoin surging along with it...',
#    'url': 'https://www.forbes.com/sites/billybambrough/2021/12/28/is-this-why-bitcoin-ethereum-litecoin-and-other-cryptocurrencies-have-suddenly-shot-higher/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5fe9b1915699fc991df64e74%2F0x0.jpg',
#    'publishedAt': '2020-12-28T10:55:41Z',
#    'content': 'Bitcoin has continued its huge December rally over the last few days, climbing to a total value of around half a trillion dollars ($500 billion). \r\nThe bitcoin price, breaking $28,000 per bitcoin for… [+2998 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Billy Bambrough, Contributor, \n Billy Bambrough, Contributor\n https://www.forbes.com/sites/billybambrough/',
#    'title': 'As Bitcoin, Ethereum, Ripple’s XRP And Litecoin Lose Billions, Watchdog Issues Stark Warning',
#    'description': 'As the bitcoin and cryptocurrency market wobbles, the U.K. financial watchdog has issued a stark to people considering trying to jump onto the crypto bandwagon—you "should be prepared to lose all their money"...',
#    'url': 'https://www.forbes.com/sites/billybambrough/2021/01/11/as-bitcoin-ethereum-ripples-xrp-and-litecoin-lose-billions-watchdog-issues-stark-warning/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5ffc1bc883d0e8c00e070350%2F0x0.jpg',
#    'publishedAt': '2021-01-11T09:50:00Z',
#    'content': 'Bitcoin, after surging non-stop for the last few weeks, has finally taken a breather. \r\nThe bitcoin price has dropped around 15% in the last 24 hours, dragging down the wider cryptocurrency market an… [+4314 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Mark DeCambre',
#    'title': 'The Tell: Here’s how bitcoin could soon be worth $146,000 according to JPMorgan',
#    'description': 'JPMorgan researchers point to outflows from gold-pegged exchange traded funds, or ETFs, and inflows into a digital-currency focused trusts sponsored by Grayscale, for example, as part of the evidence pointing to increased use of bitcoin as a gold-like asset, …',
#    'url': 'https://www.marketwatch.com/story/heres-how-bitcoin-could-soon-be-worth-146-000-says-jpmorgan-11609869356',
#    'urlToImage': 'https://images.mktw.net/im-280789/social',
#    'publishedAt': '2021-01-05T18:04:00Z',
#    'content': 'Bitcoins nearly nonstop climb to new records has drawn the attention of Wall Street like few other securities in recent memory. The worlds No. 1 digital asset was recently trading at around $32,000 i… [+3472 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Chris Markoch',
#    'title': 'The Party May Just Be Starting For Litecoin',
#    'description': 'Frequently known as the silver to bitcoin’s (CCC:BTC) gold, the time may be right for investors to invest in litecoin (CCC:LTC). One of the oldest altcoins, ...',
#    'url': 'https://finance.yahoo.com/news/party-may-just-starting-litecoin-182502232.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/QGHkmnzxn5LViUBTKahP4A--~B/aD00MDA7dz03Mjg7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/investorplace_417/5cf0ba1ef486b3cd57d4ec70777e76b1',
#    'publishedAt': '2021-01-15T18:25:02Z',
#    'content': 'Frequently known as the silver to bitcoins (CCC:BTC) gold, the time may be right for investors to invest in litecoin (CCC:LTC). One of the oldest altcoins, litecoin has jumped over 85% since Dec. 10.… [+5042 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – January 13th, 2021',
#    'description': 'It’s a bearish start to the day for the majors. Failure to move through the day’s pivot levels would leave support levels in play.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-001921667.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/Uc3MqFG5fv2PFZX.FPcb1Q--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/3a57df7b01e97b345757d5e7291d135c',
#    'publishedAt': '2021-01-13T00:19:21Z',
#    'content': 'Ethereum\r\nEthereum fell by 3.56% on Tuesday. Following on from Mondays 13.25% tumble, Ethereum ended the day at $1,049.79.\r\nIt was a choppy day. Ethereum fell to an early morning low $1,040.00 before… [+5947 chars]'},
#   {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#    'author': 'Bob Mason',
#    'title': 'Ethereum, Litecoin, and Ripple’s XRP – Daily Tech Analysis – January 16th, 2021',
#    'description': 'It’s a bullish start to the day for the majors. A move through Friday’s highs would support a breakout on the day.',
#    'url': 'https://finance.yahoo.com/news/ethereum-litecoin-ripple-xrp-daily-002733695.html',
#    'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/ZSONKx4tMF9lqYa.0XCxfw--~B/aD00MTA7dz02MTU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/fx_empire_176/657cd4df227529d12b0dfdfad9feaa42',
#    'publishedAt': '2021-01-16T00:27:33Z',
#    'content': 'Ethereum\r\nEthereum slid by 5.16% on Friday. Partially reversing an 8.89% rally from Thursday, Ethereum ended the day at $1,168.1.\r\nA bullish start to the day saw Ethereum rise to an early morning int… [+5569 chars]'},
#   {'source': {'id': None, 'name': 'FX Empire'},
#    'author': None,
#    'title': "Ethereum, Litecoin, and Ripple's XRP – Daily Tech Analysis – December 25th, 2020 - FX Empire",
#    'description': 'It&#039;s a bearish start to the day for the majors. Steering clear of the day&#039;s pivot levels, however, would bring resistance levels into play.',
#    'url': 'https://www.fxempire.com/forecasts/article/ethereum-litecoin-and-ripples-xrp-daily-tech-analysis-december-25th-2020-690657',
#    'urlToImage': 'https://responsive.fxempire.com/width/600/webp-lossy-70.q50/_fxempire_/2020/12/All-Crypto-Coins-4.jpg',
#    'publishedAt': '2020-12-25T00:31:09Z',
#    'content': 'For the day ahead\r\nEthereum would need to avoid a fall through the pivot level at $597.62 to support a run at the first major resistance level at $629.64.\r\nSupport from the broader market would be ne… [+1718 chars]'}]}

# %%
# Create the S&P 500 sentiment scores DataFrame
spy_sentiments = []

for article in spy_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        spy_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
spy_sent_df = pd.DataFrame(spy_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
spy_sent_df = spy_sent_df[cols]

spy_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-31  That’s something you won’t find on services fr...    0.2732
# 1  2021-01-19  Apple today announced a new editorial franchis...    0.3400
# 2  2021-01-20  Apple is extending free repair eligibility for...    0.5106
# 3  2021-01-19  Apple is expanding its free trial program to g...    0.6249
# 4  2021-01-15  Apple will once again give some of its custome...    0.5106
#
#    positive  negative  neutral
# 0     0.063     0.000    0.937
# 1     0.072     0.000    0.928
# 2     0.096     0.000    0.904
# 3     0.180     0.054    0.765
# 4     0.084     0.000    0.916

# %%
# Create the Finance Sector sentiment scores DataFrame
financial_sentiments = []

for article in finance_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        financial_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
financial_sent_df = pd.DataFrame(financial_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
financial_sent_df = financial_sent_df[cols]

financial_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-30  Third Point, the activist hedge fund run by Da...    0.4833
# 1  2021-01-12  Value stocks are set to outperform in 2021, as...    0.6124
# 2  2021-01-13  (Reuters) - American casino mogul Sheldon Adel...    0.6705
# 3  2021-01-06  (Bloomberg) -- Following are the minutes of th...    0.0000
# 4  2021-01-05  Predicting what's going to happen in 2021 take...    0.4118
#
#    positive  negative  neutral
# 0     0.093     0.045    0.862
# 1     0.139     0.000    0.861
# 2     0.151     0.000    0.849
# 3     0.000     0.000    1.000
# 4     0.097     0.000    0.903

# %%
# Create the Technology Sector sentiment scores DataFrame
technology_sentiments = []

for article in tech_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        technology_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
technology_sent_df = pd.DataFrame(technology_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
technology_sent_df = technology_sent_df[cols]

technology_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-16  The company won the FAA’s trust by testing its...    0.7906
# 1  2021-01-11  A new law to follow seems unlikely to have fea...    0.4810
# 2  2021-01-04  January\r\n4, 2021\r\n5 min read\r\nOpinions e...    0.0000
# 3  2021-01-05  Predicting what's going to happen in 2021 take...    0.4118
# 4  2021-01-15  The Fine Print: The following comments are own...   -0.0418
#
#    positive  negative  neutral
# 0     0.171     0.000    0.829
# 1     0.087     0.000    0.913
# 2     0.000     0.000    1.000
# 3     0.097     0.000    0.903
# 4     0.079     0.086    0.835

# %%
# Create the Telecom Sector sentiment scores DataFrame
telecom_sentiments = []

for article in telecom_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        telecom_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
telecom_sent_df = pd.DataFrame(telecom_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
telecom_sent_df = telecom_sent_df[cols]

telecom_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-12  Value stocks are set to outperform in 2021, as...    0.6124
# 1  2021-01-19  MEXICO CITY (Reuters) - Mexicos government is ...    0.2732
# 2  2021-01-02  Police bodycam video shows officers rushing pe...   -0.4939
# 3  2021-01-08  WASHINGTON (Reuters) - President-elect Joe Bid...    0.0000
# 4  2021-01-05  A group of Google employees has formed a union...    0.1779
#
#    positive  negative  neutral
# 0     0.139     0.000    0.861
# 1     0.065     0.000    0.935
# 2     0.000     0.091    0.909
# 3     0.000     0.000    1.000
# 4     0.055     0.000    0.945

# %%
# Create the Utilities Sector sentiment scores DataFrame
utility_sentiments = []

for article in utility_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        utility_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
utility_sent_df = pd.DataFrame(utility_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
utility_sent_df = utility_sent_df[cols]

utility_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-05  Predicting what's going to happen in 2021 take...    0.4118
# 1  2021-01-12  Value stocks are set to outperform in 2021, as...    0.6124
# 2  2021-01-20  President Joe Biden is directing the U.S. to r...    0.2732
# 3  2021-01-19  We asked our Foolish writers for their top ide...    0.1280
# 4  2021-01-12  American greenhouse gas emissions fell a recor...   -0.5994
#
#    positive  negative  neutral
# 0     0.097     0.000    0.903
# 1     0.139     0.000    0.861
# 2     0.088     0.058    0.854
# 3     0.095     0.056    0.849
# 4     0.000     0.115    0.885

# %%
# Create the Industrial Sector sentiment scores DataFrame
industrial_sentiments = []

for article in indust_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        industrial_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
industrial_sent_df = pd.DataFrame(industrial_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
industrial_sent_df = industrial_sent_df[cols]

industrial_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-11  A new law to follow seems unlikely to have fea...    0.4810
# 1  2021-01-12  Value stocks are set to outperform in 2021, as...    0.6124
# 2  2020-12-29  By Reuters Staff\r\n(Adds detail)\r\nWARSAW, D...   -0.2103
# 3  2020-12-30  * Brazil stocks hit record intraday high; over...    0.2263
# 4  2021-01-16  Pro-Trump protesters and police clash on top o...    0.5160
#
#    positive  negative  neutral
# 0     0.087     0.000    0.913
# 1     0.139     0.000    0.861
# 2     0.000     0.058    0.942
# 3     0.095     0.070    0.836
# 4     0.188     0.100    0.712

# %%
# Create the Healthcare Sector sentiment scores DataFrame
healthcare_sentiments = []

for article in health_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        healthcare_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
healthcare_sent_df = pd.DataFrame(healthcare_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
healthcare_sent_df = healthcare_sent_df[cols]

healthcare_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-30  Third Point, the activist hedge fund run by Da...    0.4833
# 1  2021-01-07  By Reuters Staff\r\n(Updates prices to add mil...    0.6486
# 2  2021-01-07  By Reuters Staff\r\nJan 7 (Reuters) - Canadas ...    0.6486
# 3  2021-01-07  By Reuters Staff\r\n(Updates prices to add mil...    0.6486
# 4  2021-01-07  HONG KONG (Reuters) - European companies are e...    0.1779
#
#    positive  negative  neutral
# 0     0.093     0.045    0.862
# 1     0.138     0.000    0.862
# 2     0.146     0.000    0.854
# 3     0.138     0.000    0.862
# 4     0.054     0.000    0.946

# %%
# Create the Energy Sector sentiment scores DataFrame
energy_sentiments = []

for article in energy_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        energy_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
energy_sent_df = pd.DataFrame(energy_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
energy_sent_df = energy_sent_df[cols]

energy_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2021-01-16  The company won the FAA’s trust by testing its...    0.7906
# 1  2021-01-12  A group of former displaced persons helps to l...    0.7845
# 2  2021-01-11  A new law to follow seems unlikely to have fea...    0.4810
# 3  2021-01-15  FILE PHOTO: Mexico's Energy Minister Rocio Nah...    0.2732
# 4  2021-01-18  PARIS (Reuters) - Total is paying $2.5 billion...    0.6369
#
#    positive  negative  neutral
# 0     0.171     0.000    0.829
# 1     0.198     0.000    0.802
# 2     0.087     0.000    0.913
# 3     0.068     0.000    0.932
# 4     0.208     0.049    0.744

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
ethereum_sent_df = pd.DataFrame(ethereum_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
ethereum_sent_df = ethereum_sent_df[cols]

ethereum_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-22  The Securities and Exchange Commission plans t...    0.5267
# 1  2021-01-05  Cryptocurrencies stole headlines on the first ...    0.3412
# 2  2020-12-21  NEW YORK (Reuters) - Total investor inflows in...    0.3612
# 3  2021-01-04  Ethereum creator Vitalik Buterin.\r\n14 with 1...    0.5256
# 4  2021-01-04  Bitcoin fizzled in Monday trading as the famou...   -0.2732
#
#    positive  negative  neutral
# 0     0.136      0.00    0.864
# 1     0.074      0.00    0.926
# 2     0.068      0.00    0.932
# 3     0.099      0.00    0.901
# 4     0.000      0.06    0.940

# %%
# Create the Litecoin sentiment scores DataFrame
litecoin_sentiments = []

for article in lite_headlines["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        litecoin_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
# Create DataFrame
litecoin_sent_df = pd.DataFrame(litecoin_sentiments)

# Reorder DataFrame columns
cols = ["date", "text", "compound", "positive", "negative", "neutral"]
litecoin_sent_df = litecoin_sent_df[cols]

litecoin_sent_df.head()
# Out:
#          date                                               text  compound  \
# 0  2020-12-23  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
# 1  2020-12-23  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
# 2  2020-12-29  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
# 3  2021-01-07  1 with 1 posters participating\r\nThe world's ...    0.5106
# 4  2020-12-23  By Reuters Staff\r\nFILE PHOTO: Representation...    0.0000
#
#    positive  negative  neutral
# 0     0.000       0.0    1.000
# 1     0.000       0.0    1.000
# 2     0.000       0.0    1.000
# 3     0.125       0.0    0.875
# 4     0.000       0.0    1.000

# %%
# Describe the S&P 500 Sentiment
spy_sent_df.describe()
# Out:
#         compound   positive  negative    neutral
# count  20.000000  20.000000  20.00000  20.000000
# mean    0.291605   0.091700   0.02945   0.878850
# std     0.396736   0.079577   0.03694   0.083396
# min    -0.340000   0.000000   0.00000   0.724000
# 25%    -0.019300   0.036750   0.00000   0.808750
# 50%     0.380750   0.078000   0.00000   0.902000
# 75%     0.625425   0.134000   0.06100   0.933250
# max     0.895700   0.276000   0.12500   1.000000

# %%
# Describe the Finance Sector Sentiment
financial_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.219475   0.073450   0.023000   0.903550
# std     0.308904   0.057123   0.044042   0.073741
# min    -0.250000   0.000000   0.000000   0.798000
# 25%     0.000000   0.040500   0.000000   0.851250
# 50%     0.177900   0.071500   0.000000   0.894500
# 75%     0.429675   0.101250   0.011250   0.959500
# max     0.771700   0.199000   0.128000   1.000000

# %%
# Describe the Technology Sector Sentiment
technology_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.148215   0.058800   0.027000   0.914200
# std     0.380140   0.060611   0.051522   0.071002
# min    -0.612400   0.000000   0.000000   0.810000
# 25%     0.000000   0.000000   0.000000   0.855500
# 50%     0.000000   0.056500   0.000000   0.894500
# 75%     0.429100   0.108000   0.016500   1.000000
# max     0.790600   0.171000   0.152000   1.000000

# %%
# Describe the Telecom Sector Sentiment
telecom_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.160515   0.073400   0.036850   0.889700
# std     0.470207   0.083424   0.083792   0.101684
# min    -0.936000   0.000000   0.000000   0.638000
# 25%     0.000000   0.000000   0.000000   0.821500
# 50%     0.152950   0.058500   0.000000   0.912500
# 75%     0.523525   0.148500   0.051500   0.958750
# max     0.765000   0.220000   0.362000   1.000000

# %%
# Describe the Utilities Sector Sentiment
utility_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.354030   0.117650   0.036100   0.846300
# std     0.405962   0.096003   0.042896   0.117148
# min    -0.599400   0.000000   0.000000   0.617000
# 25%     0.219500   0.073500   0.000000   0.784750
# 50%     0.396800   0.091500   0.000000   0.879500
# 75%     0.602650   0.155500   0.079250   0.921250
# max     0.862500   0.294000   0.115000   1.000000

# %%
# Describe the Industrial Sector Sentiment
industrial_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.139825   0.057600   0.032250   0.910200
# std     0.333271   0.069697   0.035194   0.081146
# min    -0.440400   0.000000   0.000000   0.712000
# 25%    -0.128000   0.000000   0.000000   0.863250
# 50%     0.051350   0.021500   0.024500   0.937000
# 75%     0.489750   0.103250   0.058000   0.954750
# max     0.690100   0.202000   0.100000   1.000000

# %%
# Describe the Healthcare Sector Sentiment
healthcare_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  18.000000  18.000000  18.000000  18.000000
# mean    0.250383   0.082111   0.023667   0.894222
# std     0.441569   0.071073   0.053497   0.075098
# min    -0.709600   0.000000   0.000000   0.781000
# 25%     0.000000   0.010750   0.000000   0.850250
# 50%     0.177900   0.073500   0.000000   0.862000
# 75%     0.648600   0.138000   0.000000   0.946000
# max     0.827100   0.219000   0.182000   1.000000

# %%
# Describe the Energy Sector Sentiment
energy_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.355920   0.099950   0.016800   0.883250
# std     0.352119   0.064687   0.039193   0.076467
# min    -0.585900   0.000000   0.000000   0.744000
# 25%     0.038700   0.065000   0.000000   0.827750
# 50%     0.446400   0.105500   0.000000   0.863000
# 75%     0.639825   0.138250   0.000000   0.932750
# max     0.790600   0.208000   0.150000   1.000000

# %%
# Describe the Ethereum Sector Sentiment
ethereum_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.135816   0.042158   0.009789   0.948053
# std     0.318021   0.060099   0.023273   0.057291
# min    -0.381800   0.000000   0.000000   0.845000
# 25%     0.000000   0.000000   0.000000   0.913500
# 50%     0.000000   0.000000   0.000000   0.941000
# 75%     0.435900   0.086500   0.000000   1.000000
# max     0.636900   0.155000   0.067000   1.000000

# %%
# Describe the Litecoin Sentiment
litecoin_sent_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.212842   0.054947   0.008789   0.936211
# std     0.295330   0.066625   0.020893   0.075552
# min    -0.273200   0.000000   0.000000   0.767000
# 25%     0.000000   0.000000   0.000000   0.871500
# 50%     0.000000   0.000000   0.000000   0.962000
# 75%     0.518100   0.127500   0.000000   1.000000
# max     0.636900   0.178000   0.060000   1.000000

# %% [markdown]
# ---
